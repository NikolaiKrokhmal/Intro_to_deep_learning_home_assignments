# %% [markdown]
# # Assignment 2. Music Century Classification
#
# For this task, we will construct models to predict the century in which a music piece was released. We will utilize the "YearPredictionMSD Data Set," which is derived from the Million Song Dataset from the UCI Machine Learning Repository. Make sure you download the version of the dataset from the moodle and not from UCI. Here are some relevant links to read on this dataset:
#
# - https://archive.ics.uci.edu/ml/datasets/yearpredictionmsd
# - http://millionsongdataset.com/pages/tasks-demos/#yearrecognition
#
# Just like in the last assignment, it is divided to two files.
# 1. This file (ML_DL_Assignment2.ipynb)
# 2. A python functions  file which you will fill out (ML_DL_Functions2.py)
#
# As well as the year prediction msd dataset file.
#
# In this assignment you will mount and load the dataset and functions file from google drive. To start make sure you have both the template python functions file and the song dataset file(downloaded from the moodle) on the same directory in your google drive.
#
# When you are finished with the assignment make sure you submit the following files:
# 1. this file (ML_DL_Assignment2.ipynb).
# 2. the functions file (ML_DL_Functions2.py).
# 3. the weights file from section 2.7 (assignment2_submission_optimal_weights.npy).
# 4. the bias file from section 2.7 (assignment2_submission_optimal_bias.npy).
#
# **Make sure you fill your personal ID in the functions file in the return value of function ID1. ID2 is filled only if you were allowed to complete the assignment in pairs otherwise keep it's return value 0.**
#
# Note that untill section 2.9 you are not allowed to import additional packages **(especially not PyTorch)**. One of the objectives is to understand how the training procedure actually operates, before working with PyTorch's autograd engine which does it all for us. Importing the pytorch package will deduct from your points.

# %% [markdown]
# ## 1. Data

# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt
import sys
def reload_functions():
  if 'ML_DL_Functions2' in sys.modules:
    del sys.modules['ML_DL_Functions2']
  functions_path = drive_path.replace(" ","\ ") + 'ML_DL_Functions2.py'
  # !cp $functions_path .

# %% [markdown]
# Just like in the last assignment you should mount your google drive and make sure you have both the dataset from the moodle('YearPredictionMSD.csv') and the functions file ('ML_DL_Functions2.py') in the same directory which you will input below:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
drive_path = '/content/gdrive/My Drive/introML/HW2/' # TODO - UPDATE ME WITH THE TRUE PATH!
csv_path = drive_path + 'YearPredictionMSD.csv'
t_label = ["year"]
x_labels = ["var%d" % i for i in range(1, 91)]
df = pandas.read_csv(csv_path)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Now that the data is loaded to your Colab notebook, you should be able to display the Pandas
# DataFrame `df` as a table:

# %%
df
# Out:
#         year      var1      var2      var3      var4      var5      var6  \
# 0       2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905
# 1       2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777
# 2       2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940
# 3       2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683
# 4       2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409
# ...      ...       ...       ...       ...       ...       ...       ...
# 508710  1979  42.88385 -17.41629 -13.51726  -0.75243   4.74785  14.33437
# 508711  2010  42.47120  13.16539  -6.89795  14.78750  14.72776 -12.05820
# 508712  2010  45.21104 -19.03522 -16.50919  19.30722 -22.23290 -25.77296
# 508713  2004  44.60991  29.26510 -14.79970  16.26654 -20.44287  34.93228
# 508714  2002  51.58607  62.50479  10.33764  -7.60272 -35.88361 -30.27671
#
#             var7      var8      var9  ...     var81      var82     var83  \
# 0      -25.01202 -12.23257   7.83089  ...  13.01620  -54.40548  58.99367
# 1        8.76630  -0.92019  18.76548  ...   5.66812  -19.68073  33.04964
# 2       -3.27872  -2.35035  16.07017  ...   3.03800   26.05866 -50.92779
# 3        5.05097 -10.34124   3.55005  ...  34.57337 -171.70734 -16.96705
# 4      -12.48207  -9.37636  12.63699  ...   9.92661  -55.95724  64.92712
# ...          ...       ...       ...  ...       ...        ...       ...
# 508710 -11.75670 -10.46058 -14.91937  ... -23.01045 -169.62524  43.90683
# 508711  -6.56437  -7.70141  -8.01135  ...   6.97510   97.98602 -45.39312
# 508712  15.66504  -3.26132   1.78980  ...  17.64373   27.46728  48.64159
# 508713  -8.15282   2.94035  -1.93460  ...  21.30827 -183.32526 -40.60815
# 508714   7.36746   0.33782   5.51725  ...   0.57308   34.69757 -22.81646
#
#            var84     var85      var86      var87     var88      var89  \
# 0       15.37344   1.11144  -23.08793   68.40795  -1.82223  -27.46348
# 1       42.87836  -9.90378  -32.22788   70.49388  12.04941   58.43453
# 2       10.93792  -0.07568   43.20130 -115.00698  -0.05859   39.67068
# 3      -46.67617 -12.51516   82.58061  -72.08993   9.90558  199.62971
# 4      -17.72522  -1.49237   -7.50035   51.76631   7.88713   55.66926
# ...          ...       ...        ...        ...       ...        ...
# 508710  15.45299   2.84499   94.83469 -157.26665   3.60034   54.26775
# 508711 -30.26953  -9.49116  -51.58060  -12.08770   0.10696  117.82374
# 508712  92.03877  11.31597 -189.77886  179.06219  -3.74635  -27.01421
# 508713  19.53727  12.13429 -133.10456 -158.46478  22.36919  161.58392
# 508714  27.20861  -1.22381   -8.51102  -18.26440   2.22031  -93.94392
#
#            var90
# 0        2.26327
# 1       26.92061
# 2       -0.66345
# 3       18.85382
# 4       28.74903
# ...          ...
# 508710 -22.24375
# 508711  -1.06577
# 508712 -10.23084
# 508713 -18.54131
# 508714  -6.75431
#
# [508715 rows x 91 columns]

# %% [markdown]
# To set up our data for classification, we'll use the "year" field to represent
# whether a song was released in the 20-th century. In our case `df["year"]` will be 1 if
# the year was released after 2000, and 0 otherwise.

# %%
df["year"] = df["year"].map(lambda x: int(x > 2000))

# %%
df.head(20)
# Out:
#     year      var1       var2      var3      var4      var5      var6  \
# 0      1  49.94357   21.47114  73.07750   8.74861 -17.40628 -13.09905
# 1      1  48.73215   18.42930  70.32679  12.94636 -10.32437 -24.83777
# 2      1  50.95714   31.85602  55.81851  13.41693  -6.57898 -18.54940
# 3      1  48.24750   -1.89837  36.29772   2.58776   0.97170 -26.21683
# 4      1  50.97020   42.20998  67.09964   8.46791 -15.85279 -16.81409
# 5      1  50.54767    0.31568  92.35066  22.38696 -25.51870 -19.04928
# 6      1  50.57546   33.17843  50.53517  11.55217 -27.24764  -8.78206
# 7      1  48.26892    8.97526  75.23158  24.04945 -16.02105 -14.09491
# 8      1  49.75468   33.99581  56.73846   2.89581  -2.92429 -26.44413
# 9      1  45.17809   46.34234 -40.65357  -2.47909   1.21253  -0.65302
# 10     1  39.13076  -23.01763 -36.20583   1.67519  -4.27101  13.01158
# 11     1  37.66498  -34.05910 -17.36060 -26.77781 -39.95119 -20.75000
# 12     1  26.51957 -148.15762 -13.30095  -7.25851  17.22029 -21.99439
# 13     1  37.68491  -26.84185 -27.10566 -14.95883  -5.87200 -21.68979
# 14     0  39.11695   -8.29767 -51.37966  -4.42668 -30.06506 -11.95916
# 15     1  35.05129  -67.97714 -14.20239  -6.68696  -0.61230 -18.70341
# 16     1  33.63129  -96.14912 -89.38216 -12.11699  13.77252  -6.69377
# 17     0  41.38639  -20.78665  51.80155  17.21415 -36.44189 -11.53169
# 18     0  37.45034   11.42615  56.28982  19.58426 -16.43530   2.22457
# 19     0  39.71092   -4.92800  12.88590 -11.87773   2.48031 -16.11028
#
#         var7      var8      var9  ...     var81      var82      var83  \
# 0  -25.01202 -12.23257   7.83089  ...  13.01620  -54.40548   58.99367
# 1    8.76630  -0.92019  18.76548  ...   5.66812  -19.68073   33.04964
# 2   -3.27872  -2.35035  16.07017  ...   3.03800   26.05866  -50.92779
# 3    5.05097 -10.34124   3.55005  ...  34.57337 -171.70734  -16.96705
# 4  -12.48207  -9.37636  12.63699  ...   9.92661  -55.95724   64.92712
# 5   20.67345  -5.19943   3.63566  ...   6.59753  -50.69577   26.02574
# 6  -12.04282  -9.53930  28.61811  ...  11.63681   25.44182  134.62382
# 7    8.11871  -1.87566   7.46701  ...  18.03989  -58.46192  -65.56438
# 8    1.71392  -0.55644  22.08594  ...  18.70812    5.20391  -27.75192
# 9   -6.95536 -12.20040  17.02512  ...  -4.36742  -87.55285  -70.79677
# 10   8.05718  -8.41088   6.27370  ...  32.86051  -26.08461 -186.82429
# 11  -0.10231  -0.89972  -1.30205  ...  11.18909   45.20614   53.83925
# 12   5.51947   3.48418   2.61738  ...  23.80442  251.76360   18.81642
# 13   4.87374 -18.01800   1.52141  ... -67.57637  234.27192  -72.34557
# 14  -0.85322  -8.86179  11.36680  ...  42.22923  478.26580  -10.33823
# 15  -1.31928  -9.46370   5.53492  ...  10.25585   94.90539   15.95689
# 16 -33.36843 -24.81437  21.22757  ...  49.93249  -14.47489   40.70590
# 17  11.75252  -7.62428  -3.65488  ...  50.37614  -40.48205   48.07805
# 18   1.02668  -7.34736  -0.01184  ... -22.46207  -25.77228 -322.42841
# 19 -16.40421  -8.29657   9.86817  ...  11.92816  -73.72412   16.19039
#
#         var84     var85      var86      var87     var88       var89     var90
# 0    15.37344   1.11144  -23.08793   68.40795  -1.82223   -27.46348   2.26327
# 1    42.87836  -9.90378  -32.22788   70.49388  12.04941    58.43453  26.92061
# 2    10.93792  -0.07568   43.20130 -115.00698  -0.05859    39.67068  -0.66345
# 3   -46.67617 -12.51516   82.58061  -72.08993   9.90558   199.62971  18.85382
# 4   -17.72522  -1.49237   -7.50035   51.76631   7.88713    55.66926  28.74903
# 5    18.94430  -0.33730    6.09352   35.18381   5.00283   -11.02257   0.02263
# 6    21.51982   8.17570   35.46251   11.57736   4.50056    -4.62739   1.40192
# 7    46.99856  -4.09602   56.37650  -18.29975  -0.30633     3.98364  -3.72556
# 8    17.22100  -0.85210  -15.67150  -26.36257   5.48708    -9.13495   6.08680
# 9    76.57355  -7.71727    3.26926 -298.49845  11.49326   -89.21804 -15.09719
# 10  113.58176   9.28727   44.60282  158.00425  -2.59543   109.19723  23.36143
# 11    2.59467  -4.00958  -47.74886 -170.92864  -5.19009     8.83617  -7.16056
# 12  157.09656 -27.79449 -137.72740  115.28414  23.00230  -164.02536  51.54138
# 13 -362.25101 -25.55019  -89.08971 -891.58937  14.11648 -1030.99180  99.28967
# 14 -103.76858  39.19511  -98.76636 -122.81061  -2.14942  -211.48202 -12.81569
# 15  -98.15732  -9.64859  -93.52834  -95.82981  20.73063  -562.07671  43.44696
# 16   58.63692   8.81522   27.28474    5.78046   3.44539   259.10825  10.28525
# 17   -7.62399   6.51934  -30.46090  -53.87264   4.44627    58.16913  -0.02409
# 18 -146.57408  13.61588   92.22918 -439.80259  25.73235   157.22967  38.70617
# 19    9.79606   9.71693   -9.90907  -20.65851   2.34002   -31.57015   1.58400
#
# [20 rows x 91 columns]

# %% [markdown]
# ### 1.1 - Train Test Split
#
# The data set description text asks us to respect the below train/test split to
# avoid the "producer effect". That is, we want to make sure that no song from a single artist
# ends up in both the training and test set.
#
# #### Food for thought:
# why would it be problematic to have some songs from an artist in the training set, and other songs from the same artist in the test set. (Hint: Remember that we want our test accuracy to predict how well the model will perform in practice on a song it hasn't learned about.)

# %%
# train test split
df_train = df[:463715]
df_test = df[463715:]

# convert to numpy
train_xs = df_train[x_labels].to_numpy()
train_ts = df_train[t_label].to_numpy()
test_xs = df_test[x_labels].to_numpy()
test_ts = df_test[t_label].to_numpy()

# %% [markdown]
# ### Part (b) -- 7%
# Normalize the data by subtracting the mean and dividing by the std just like the last assignment.

# %%
# Insert your code here:
mean = np.mean(train_xs, axis=0)
variance = np.std(train_xs, axis=0)
train_norm_xs = (train_xs-mean)/variance
test_norm_xs = (test_xs-mean)/variance

# %% [markdown]
# ### Part (c) -- 7%
#
# Finally, we'll move some of the data in our training set into a validation set.
# #### Food for thought:
# Why should we limit how many times we use the test set, and how do we use the validation set during the model building process?

# %%
# shuffle the training set
reindex = np.random.permutation(len(train_xs))
train_xs = train_xs[reindex]
train_norm_xs = train_norm_xs[reindex]
train_ts = train_ts[reindex]
# use the first 50000 elements of `train_xs` as the validation set
train_xs, val_xs           = train_xs[50000:], train_xs[:50000]
train_norm_xs, val_norm_xs = train_norm_xs[50000:], train_norm_xs[:50000]
train_ts, val_ts           = train_ts[50000:], train_ts[:50000]

# %% [markdown]
# ## Part 2. Classification (79%)
#
# We will first build a *classification* model to perform decade classification. We have written a few helper functions for you. You can find them in your functions file ('sigmoid', 'cross_entropy' and 'get_accuracy'). All other code that you write in this section should be vectorized whenever possible (i.e., avoid unnecessary loops). Feel free to add more testing to the notebook to validate your code in the functions file.

# %% [markdown]
# ### 2.1 Prediction
#
# Fill in the function `pred` in the functions file that computes the prediction `y` based on logistic regression, i.e., a single layer with weights `w` and bias `b`. The output is given by:
# \begin{equation}
# y = \sigma({\bf w}^T {\bf x} + b),
# \end{equation}
# where the value of $y$ is an estimate of the probability that the song is released in the current century, namely ${\rm year} =1$.

# %%
reload_functions()
import ML_DL_Functions2
ML_DL_Functions2.pred(np.zeros(90), 1, np.ones([2, 90]))
# Out:
# array([0.73105858, 0.73105858])

# %% [markdown]
# ### 2.2 Cost
# Assuming the loss function is the cross entropy function fill in the cost(risk) function in the functions file which returns the mean of the loss function on all inputs.
# $$\mathcal{L}_\mathcal{P}(\text{Cross Entropy}) = \mathbb{E}_{(y,t)\sim\mathcal{P}}\left\{\text{CE}(t,s)\right\}$$

# %%
reload_functions()
import ML_DL_Functions2
print(ML_DL_Functions2.cost(0.5*np.ones(4), np.ones(4)))
# Out:
# 0.6931471805599453

# %% [markdown]
# ### 2.3 Derivative of the cost -- 7%
# Take a pen and paper and calculate the analytical derivative of the cost function with respect to the weights and bias. use the formula calculated to fill in the function `derivative_cost` that computes and returns the gradients
# $\frac{\partial\mathcal{L}}{\partial {\bf w}}$ and
# $\frac{\partial\mathcal{L}}{\partial b}$. Here, `X` is the input, `y` is the prediction, and `t` is the true label.

# %%
reload_functions()
import ML_DL_Functions2
dldw, dldb = ML_DL_Functions2.derivative_cost(np.ones([10,90]), np.ones(10), np.ones(10))
print(dldw.shape)
print(type(dldb))
# Out:
# (90,)
# <class 'numpy.float64'>

# %% [markdown]
# ### 2.4 Derivative approximation
#
# We can check that our derivative is implemented correctly using the finite difference rule. In 1D, the
# finite difference rule tells us that for small $h$, we should have
#
# $$\frac{f(x+h) - f(x)}{h} \approx f'(x)$$
#
# make sure that $\frac{\partial\mathcal{L}}{\partial b}$  is implement correctly
# by comparing the result from `derivative_cost` with the empirical cost derivative computed using the above numerical approximation.

# %%
reload_functions()
import ML_DL_Functions2
# Your code goes here
h = 10**-8
x = np.ones([2, 90])
w = np.zeros(90)
t = np.ones(2)
b = 1
bph = b + h

# Calculating derivative analiticaly
predicitions = ML_DL_Functions2.pred(w,b,x)
dldw, dldb = ML_DL_Functions2.derivative_cost(x, predicitions, t)
r1 = dldb

# Calculating derivative numericaly
predictionsH = ML_DL_Functions2.pred(w,bph,x)
cost = ML_DL_Functions2.cost(predicitions, t)
costH = ML_DL_Functions2.cost(predictionsH, t)
r2 = (costH -cost)/h
print("The analytical results is -", r1)
print("The algorithm results is - ", r2)
# Out:
# The analytical results is - -0.2689414213699951
# The algorithm results is -  -0.26894141358368984

# %% [markdown]
# make sure that $\frac{\partial\mathcal{L}}{\partial {\bf w}}$  is implement correctly.

# %%
reload_functions()
import ML_DL_Functions2
# Your code goes here. You might find this below code helpful: but it's
# up to you to figure out how/why, and how to modify the code
r1 = dldw

r2 = np.zeros(len(r1))
for indx in range(len(r2)):
    wH = np.zeros(90)
    wH[indx] = wH[indx] +h
    costWH = ML_DL_Functions2.cost(ML_DL_Functions2.pred(wH,b,x),t)
    r2[indx] = (costWH - cost)/h
print("The analytical results is -", r1)
print("The algorithm results is - ", r2)
# Out:
# The analytical results is - [-0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142
#  -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142 -0.26894142]
# The algorithm results is -  [-0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141
#  -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141 -0.26894141]

# %% [markdown]
# ### 2.5 Gradient descent
#
# Now that you have a gradient function that works, we can actually run gradient descent.
# Complete the following code that will run stochastic: gradient descent training:

# %%
def run_gradient_descent(w0, b0, mu=0.1, batch_size=100, max_iters=100):
  """Return the values of (w, b) after running gradient descent for max_iters.
  We use:
    - train_norm_xs and train_ts as the training set
    - val_norm_xs and val_ts as the test set
    - mu as the learning rate
    - (w0, b0) as the initial values of (w, b)

  Precondition: np.shape(w0) == (90,)
                type(b0) == float

  Postcondition: np.shape(w) == (90,)
                 type(b) == float
  """
  global train_norm_xs
  global train_ts
  global val_norm_xs
  global val_ts
  w = w0
  b = b0
  iter = 0
  max_acc = 0
  opt_w = w
  opt_b = b
  cost_list = []
  acc_list  = []
  training_cost_list = []
  training_acc_list = []
  while iter < max_iters:
    # shuffle the training set (there is code above for how to do this)
    reindex = np.random.permutation(len(train_norm_xs))
    train_norm_xs = train_norm_xs[reindex]
    train_ts = train_ts[reindex]

    for i in range(0, len(train_norm_xs), batch_size): # iterate over each minibatch
      # minibatch that we are working with:
      X1 = train_norm_xs[i:(i + batch_size)]
      t1 = train_ts[i:(i + batch_size), 0]

      # since len(train_norm_xs) does not divide batch_size evenly, we will skip over
      # the "last" minibatch
      if np.shape(X1)[0] != batch_size:
        continue

      # compute the prediction
      y = ML_DL_Functions2.pred(w,b,X1)
      # calculate gradient(backpropegate)
      dLdw, dLdb = ML_DL_Functions2.derivative_cost(X1,y,t1)
      # update w and b(step)
      w = w - mu * dLdw
      b = b - mu * dLdb
      # increment the iteration count
      iter += 1
      # compute and print the *validation* loss and accuracy
      if (iter % 500 == 0):
        val_y = ML_DL_Functions2.pred(w, b, val_norm_xs)
        val_cost1 = ML_DL_Functions2.cost(val_y[:25000], val_ts[:25000].reshape(25000))
        val_cost2 = ML_DL_Functions2.cost(val_y[25000:], val_ts[25000:].reshape(25000))
        val_cost = 0.5*(val_cost1 + val_cost2)
        val_acc1 = ML_DL_Functions2.get_accuracy(val_y[:25000], val_ts[:25000].reshape(25000))
        val_acc2 = ML_DL_Functions2.get_accuracy(val_y[25000:], val_ts[25000:].reshape(25000))
        val_acc = 0.5*(val_acc1 + val_acc2)
        cost_list.append(val_cost)
        acc_list.append(val_acc)
        training_cost_list.append(ML_DL_Functions2.cost(y,t1))
        training_acc_list.append(ML_DL_Functions2.get_accuracy(y,t1))
        # save the best weights and biases
        if val_acc>max_acc:
            max_acc = val_acc
            opt_w = w
            opt_b = b

        print("Iter %d. [Val Acc %.0f%%, Loss %f]" % (
            iter, val_acc * 100, val_cost))

        if iter >= max_iters:
            break




  return opt_w, opt_b, cost_list, acc_list, training_cost_list, training_acc_list

# %% [markdown]
# ### 2.6 Running everything!
#
# Call `run_gradient_descent` with the weights and biases all initialized to zero. Test your self with different $\mu$ values and show that if mu is too small then convergance is slow and if mu is too large then the optimization algorithm does not converge. You can add more automation and plot function to help you find the best configuration.

# %%
reload_functions()
import ML_DL_Functions2
w0 = np.zeros(90)
b0 = np.zeros(1)[0]
acc = 0
loss = 1
# choose values
mu_list = [0.00001, 0.00005, 0.0001, 0.0005, 0.001, 0.005, 0.01]
max_iters = 10000
batch_size_list = [500,1000,1500,2000,2500,3000,3500,4000,4500,5000,5500,6000]


for mu in mu_list:
    for batch in batch_size_list:
        opt_w,opt_b,cost_list,acc_list , trainingLoss, trainingAcc = run_gradient_descent(w0,b0,mu,batch,max_iters)
        if cost_list[-1] < loss and acc_list[-1] > acc:
            mem_opt_w, mem_opt_b, mem_cost_list, mem_acc_list , mem_trainingLoss, mem_trainingAcc = opt_w, opt_b, cost_list, acc_list , trainingLoss, trainingAcc
            mem_mu = mu
            mem_batch = batch

plt.figure()
plt.plot(range(0,max_iters,500),mem_cost_list,"r-")
plt.plot(range(0,max_iters,500),mem_trainingLoss, "b-")
plt.title("Training Loss (blue) and Validation Loss (red) per iteration; $\mu$="+str(mem_mu)+" batch size="+str(mem_batch))
plt.figure()
plt.plot(range(0,max_iters,500),mem_acc_list,"r-")
plt.plot(range(0,max_iters,500),mem_trainingAcc, "b-")
plt.title("Training accuracy (blue) and Validation accuracy (red) per iteration; $\mu$="+str(mem_mu)+" batch size="+str(mem_batch))
# Out:
# Iter 500. [Val Acc 66%, Loss 0.692777]
# Iter 1000. [Val Acc 65%, Loss 0.692404]
# Iter 1500. [Val Acc 65%, Loss 0.692038]
# Iter 2000. [Val Acc 66%, Loss 0.691676]
# Iter 2500. [Val Acc 66%, Loss 0.691312]
# Iter 3000. [Val Acc 66%, Loss 0.690955]
# Iter 3500. [Val Acc 66%, Loss 0.690599]
# Iter 4000. [Val Acc 66%, Loss 0.690246]
# Iter 4500. [Val Acc 66%, Loss 0.689897]
# Iter 5000. [Val Acc 66%, Loss 0.689550]
# Iter 5500. [Val Acc 66%, Loss 0.689205]
# Iter 6000. [Val Acc 66%, Loss 0.688864]
# Iter 6500. [Val Acc 66%, Loss 0.688527]
# Iter 7000. [Val Acc 66%, Loss 0.688191]
# Iter 7500. [Val Acc 66%, Loss 0.687855]
# Iter 8000. [Val Acc 66%, Loss 0.687522]
# Iter 8500. [Val Acc 66%, Loss 0.687195]
# Iter 9000. [Val Acc 66%, Loss 0.686868]
# Iter 9500. [Val Acc 66%, Loss 0.686547]
# Iter 10000. [Val Acc 66%, Loss 0.686224]
# Iter 500. [Val Acc 65%, Loss 0.692773]
# Iter 1000. [Val Acc 65%, Loss 0.692403]
# Iter 1500. [Val Acc 65%, Loss 0.692038]
# Iter 2000. [Val Acc 65%, Loss 0.691673]
# Iter 2500. [Val Acc 65%, Loss 0.691313]
# Iter 3000. [Val Acc 66%, Loss 0.690953]
# Iter 3500. [Val Acc 66%, Loss 0.690598]
# Iter 4000. [Val Acc 66%, Loss 0.690247]
# Iter 4500. [Val Acc 66%, Loss 0.689897]
# Iter 5000. [Val Acc 66%, Loss 0.689550]
# Iter 5500. [Val Acc 66%, Loss 0.689205]
# Iter 6000. [Val Acc 66%, Loss 0.688864]
# Iter 6500. [Val Acc 66%, Loss 0.688525]
# Iter 7000. [Val Acc 66%, Loss 0.688189]
# Iter 7500. [Val Acc 66%, Loss 0.687855]
# Iter 8000. [Val Acc 66%, Loss 0.687524]
# Iter 8500. [Val Acc 66%, Loss 0.687193]
# Iter 9000. [Val Acc 66%, Loss 0.686868]
# Iter 9500. [Val Acc 66%, Loss 0.686545]
# Iter 10000. [Val Acc 66%, Loss 0.686224]
# Iter 500. [Val Acc 65%, Loss 0.692774]
# Iter 1000. [Val Acc 65%, Loss 0.692405]
# Iter 1500. [Val Acc 65%, Loss 0.692038]
# Iter 2000. [Val Acc 65%, Loss 0.691673]
# Iter 2500. [Val Acc 66%, Loss 0.691312]
# Iter 3000. [Val Acc 66%, Loss 0.690954]
# Iter 3500. [Val Acc 66%, Loss 0.690599]
# Iter 4000. [Val Acc 66%, Loss 0.690245]
# Iter 4500. [Val Acc 66%, Loss 0.689896]
# Iter 5000. [Val Acc 66%, Loss 0.689550]
# Iter 5500. [Val Acc 66%, Loss 0.689205]
# Iter 6000. [Val Acc 66%, Loss 0.688864]
# Iter 6500. [Val Acc 66%, Loss 0.688525]
# Iter 7000. [Val Acc 66%, Loss 0.688189]
# Iter 7500. [Val Acc 66%, Loss 0.687854]
# Iter 8000. [Val Acc 66%, Loss 0.687524]
# Iter 8500. [Val Acc 66%, Loss 0.687194]
# Iter 9000. [Val Acc 66%, Loss 0.686869]
# Iter 9500. [Val Acc 66%, Loss 0.686544]
# Iter 10000. [Val Acc 66%, Loss 0.686223]
# Iter 500. [Val Acc 65%, Loss 0.692774]
# Iter 1000. [Val Acc 65%, Loss 0.692404]
# Iter 1500. [Val Acc 65%, Loss 0.692038]
# Iter 2000. [Val Acc 65%, Loss 0.691674]
# Iter 2500. [Val Acc 65%, Loss 0.691313]
# Iter 3000. [Val Acc 66%, Loss 0.690955]
# Iter 3500. [Val Acc 66%, Loss 0.690599]
# Iter 4000. [Val Acc 66%, Loss 0.690247]
# Iter 4500. [Val Acc 66%, Loss 0.689897]
# Iter 5000. [Val Acc 66%, Loss 0.689550]
# Iter 5500. [Val Acc 66%, Loss 0.689207]
# Iter 6000. [Val Acc 66%, Loss 0.688865]
# Iter 6500. [Val Acc 66%, Loss 0.688525]
# Iter 7000. [Val Acc 66%, Loss 0.688189]
# Iter 7500. [Val Acc 66%, Loss 0.687855]
# Iter 8000. [Val Acc 66%, Loss 0.687524]
# Iter 8500. [Val Acc 66%, Loss 0.687195]
# Iter 9000. [Val Acc 66%, Loss 0.686869]
# Iter 9500. [Val Acc 66%, Loss 0.686545]
# Iter 10000. [Val Acc 66%, Loss 0.686224]
# Iter 500. [Val Acc 65%, Loss 0.692774]
# Iter 1000. [Val Acc 65%, Loss 0.692404]
# Iter 1500. [Val Acc 65%, Loss 0.692037]
# Iter 2000. [Val Acc 65%, Loss 0.691673]
# Iter 2500. [Val Acc 65%, Loss 0.691312]
# Iter 3000. [Val Acc 66%, Loss 0.690954]
# Iter 3500. [Val Acc 66%, Loss 0.690598]
# Iter 4000. [Val Acc 66%, Loss 0.690246]
# Iter 4500. [Val Acc 66%, Loss 0.689897]
# Iter 5000. [Val Acc 66%, Loss 0.689549]
# Iter 5500. [Val Acc 66%, Loss 0.689205]
# Iter 6000. [Val Acc 66%, Loss 0.688863]
# Iter 6500. [Val Acc 66%, Loss 0.688524]
# Iter 7000. [Val Acc 66%, Loss 0.688188]
# Iter 7500. [Val Acc 66%, Loss 0.687855]
# Iter 8000. [Val Acc 66%, Loss 0.687523]
# Iter 8500. [Val Acc 66%, Loss 0.687195]
# Iter 9000. [Val Acc 66%, Loss 0.686868]
# Iter 9500. [Val Acc 66%, Loss 0.686544]
# Iter 10000. [Val Acc 66%, Loss 0.686223]
# Iter 500. [Val Acc 65%, Loss 0.692774]
# Iter 1000. [Val Acc 65%, Loss 0.692404]
# Iter 1500. [Val Acc 65%, Loss 0.692037]
# Iter 2000. [Val Acc 65%, Loss 0.691674]
# Iter 2500. [Val Acc 65%, Loss 0.691312]
# Iter 3000. [Val Acc 65%, Loss 0.690954]
# Iter 3500. [Val Acc 66%, Loss 0.690599]
# Iter 4000. [Val Acc 66%, Loss 0.690246]
# Iter 4500. [Val Acc 66%, Loss 0.689897]
# Iter 5000. [Val Acc 66%, Loss 0.689549]
# Iter 5500. [Val Acc 66%, Loss 0.689205]
# Iter 6000. [Val Acc 66%, Loss 0.688864]
# Iter 6500. [Val Acc 66%, Loss 0.688525]
# Iter 7000. [Val Acc 66%, Loss 0.688188]
# Iter 7500. [Val Acc 66%, Loss 0.687855]
# Iter 8000. [Val Acc 66%, Loss 0.687523]
# Iter 8500. [Val Acc 66%, Loss 0.687195]
# Iter 9000. [Val Acc 66%, Loss 0.686869]
# Iter 9500. [Val Acc 66%, Loss 0.686545]
# Iter 10000. [Val Acc 66%, Loss 0.686224]
# Iter 500. [Val Acc 65%, Loss 0.692774]
# Iter 1000. [Val Acc 65%, Loss 0.692404]
# Iter 1500. [Val Acc 65%, Loss 0.692038]
# Iter 2000. [Val Acc 65%, Loss 0.691674]
# Iter 2500. [Val Acc 66%, Loss 0.691313]
# Iter 3000. [Val Acc 66%, Loss 0.690955]
# Iter 3500. [Val Acc 66%, Loss 0.690599]
# Iter 4000. [Val Acc 66%, Loss 0.690247]
# Iter 4500. [Val Acc 66%, Loss 0.689897]
# Iter 5000. [Val Acc 66%, Loss 0.689550]
# Iter 5500. [Val Acc 66%, Loss 0.689206]
# Iter 6000. [Val Acc 66%, Loss 0.688864]
# Iter 6500. [Val Acc 66%, Loss 0.688525]
# Iter 7000. [Val Acc 66%, Loss 0.688189]
# Iter 7500. [Val Acc 66%, Loss 0.687855]
# Iter 8000. [Val Acc 66%, Loss 0.687524]
# Iter 8500. [Val Acc 66%, Loss 0.687195]
# Iter 9000. [Val Acc 66%, Loss 0.686869]
# Iter 9500. [Val Acc 66%, Loss 0.686545]
# Iter 10000. [Val Acc 66%, Loss 0.686224]
# Iter 500. [Val Acc 65%, Loss 0.692774]
# Iter 1000. [Val Acc 65%, Loss 0.692404]
# Iter 1500. [Val Acc 65%, Loss 0.692037]
# Iter 2000. [Val Acc 65%, Loss 0.691673]
# Iter 2500. [Val Acc 66%, Loss 0.691312]
# Iter 3000. [Val Acc 66%, Loss 0.690954]
# Iter 3500. [Val Acc 66%, Loss 0.690599]
# Iter 4000. [Val Acc 66%, Loss 0.690246]
# Iter 4500. [Val Acc 66%, Loss 0.689897]
# Iter 5000. [Val Acc 66%, Loss 0.689550]
# Iter 5500. [Val Acc 66%, Loss 0.689205]
# Iter 6000. [Val Acc 66%, Loss 0.688864]
# Iter 6500. [Val Acc 66%, Loss 0.688525]
# Iter 7000. [Val Acc 66%, Loss 0.688189]
# Iter 7500. [Val Acc 66%, Loss 0.687855]
# Iter 8000. [Val Acc 66%, Loss 0.687524]
# Iter 8500. [Val Acc 66%, Loss 0.687195]
# Iter 9000. [Val Acc 66%, Loss 0.686869]
# Iter 9500. [Val Acc 66%, Loss 0.686545]
# Iter 10000. [Val Acc 66%, Loss 0.686223]
# Iter 500. [Val Acc 65%, Loss 0.692774]
# Iter 1000. [Val Acc 65%, Loss 0.692404]
# Iter 1500. [Val Acc 65%, Loss 0.692037]
# Iter 2000. [Val Acc 65%, Loss 0.691673]
# Iter 2500. [Val Acc 66%, Loss 0.691312]
# Iter 3000. [Val Acc 66%, Loss 0.690954]
# Iter 3500. [Val Acc 66%, Loss 0.690599]
# Iter 4000. [Val Acc 66%, Loss 0.690246]
# Iter 4500. [Val Acc 66%, Loss 0.689897]
# Iter 5000. [Val Acc 66%, Loss 0.689549]
# Iter 5500. [Val Acc 66%, Loss 0.689205]
# Iter 6000. [Val Acc 66%, Loss 0.688864]
# Iter 6500. [Val Acc 66%, Loss 0.688525]
# Iter 7000. [Val Acc 66%, Loss 0.688188]
# Iter 7500. [Val Acc 66%, Loss 0.687854]
# Iter 8000. [Val Acc 66%, Loss 0.687524]
# Iter 8500. [Val Acc 66%, Loss 0.687195]
# Iter 9000. [Val Acc 66%, Loss 0.686868]
# Iter 9500. [Val Acc 66%, Loss 0.686544]
# Iter 10000. [Val Acc 66%, Loss 0.686223]
# Iter 500. [Val Acc 65%, Loss 0.692774]
# Iter 1000. [Val Acc 65%, Loss 0.692404]
# Iter 1500. [Val Acc 65%, Loss 0.692037]
# Iter 2000. [Val Acc 65%, Loss 0.691673]
# Iter 2500. [Val Acc 66%, Loss 0.691312]
# Iter 3000. [Val Acc 66%, Loss 0.690954]
# Iter 3500. [Val Acc 66%, Loss 0.690599]
# Iter 4000. [Val Acc 66%, Loss 0.690247]
# Iter 4500. [Val Acc 66%, Loss 0.689896]
# Iter 5000. [Val Acc 66%, Loss 0.689549]
# Iter 5500. [Val Acc 66%, Loss 0.689205]
# Iter 6000. [Val Acc 66%, Loss 0.688864]
# Iter 6500. [Val Acc 66%, Loss 0.688525]
# Iter 7000. [Val Acc 66%, Loss 0.688188]
# Iter 7500. [Val Acc 66%, Loss 0.687854]
# Iter 8000. [Val Acc 66%, Loss 0.687523]
# Iter 8500. [Val Acc 66%, Loss 0.687194]
# Iter 9000. [Val Acc 66%, Loss 0.686868]
# Iter 9500. [Val Acc 66%, Loss 0.686544]
# Iter 10000. [Val Acc 66%, Loss 0.686223]
# Iter 500. [Val Acc 65%, Loss 0.692774]
# Iter 1000. [Val Acc 65%, Loss 0.692404]
# Iter 1500. [Val Acc 65%, Loss 0.692038]
# Iter 2000. [Val Acc 65%, Loss 0.691673]
# Iter 2500. [Val Acc 66%, Loss 0.691312]
# Iter 3000. [Val Acc 66%, Loss 0.690954]
# Iter 3500. [Val Acc 66%, Loss 0.690599]
# Iter 4000. [Val Acc 66%, Loss 0.690246]
# Iter 4500. [Val Acc 66%, Loss 0.689897]
# Iter 5000. [Val Acc 66%, Loss 0.689550]
# Iter 5500. [Val Acc 66%, Loss 0.689205]
# Iter 6000. [Val Acc 66%, Loss 0.688864]
# Iter 6500. [Val Acc 66%, Loss 0.688525]
# Iter 7000. [Val Acc 66%, Loss 0.688189]
# Iter 7500. [Val Acc 66%, Loss 0.687855]
# Iter 8000. [Val Acc 66%, Loss 0.687524]
# Iter 8500. [Val Acc 66%, Loss 0.687195]
# Iter 9000. [Val Acc 66%, Loss 0.686868]
# Iter 9500. [Val Acc 66%, Loss 0.686545]
# Iter 10000. [Val Acc 66%, Loss 0.686223]
# Iter 500. [Val Acc 65%, Loss 0.692774]
# Iter 1000. [Val Acc 65%, Loss 0.692405]
# Iter 1500. [Val Acc 65%, Loss 0.692038]
# Iter 2000. [Val Acc 65%, Loss 0.691674]
# Iter 2500. [Val Acc 65%, Loss 0.691313]
# Iter 3000. [Val Acc 66%, Loss 0.690955]
# Iter 3500. [Val Acc 66%, Loss 0.690599]
# Iter 4000. [Val Acc 66%, Loss 0.690247]
# Iter 4500. [Val Acc 66%, Loss 0.689897]
# Iter 5000. [Val Acc 66%, Loss 0.689550]
# Iter 5500. [Val Acc 66%, Loss 0.689206]
# Iter 6000. [Val Acc 66%, Loss 0.688864]
# Iter 6500. [Val Acc 66%, Loss 0.688525]
# Iter 7000. [Val Acc 66%, Loss 0.688189]
# Iter 7500. [Val Acc 66%, Loss 0.687855]
# Iter 8000. [Val Acc 66%, Loss 0.687524]
# Iter 8500. [Val Acc 66%, Loss 0.687195]
# Iter 9000. [Val Acc 66%, Loss 0.686869]
# Iter 9500. [Val Acc 66%, Loss 0.686545]
# Iter 10000. [Val Acc 66%, Loss 0.686224]
# Iter 500. [Val Acc 66%, Loss 0.691313]
# Iter 1000. [Val Acc 66%, Loss 0.689544]
# Iter 1500. [Val Acc 66%, Loss 0.687854]
# Iter 2000. [Val Acc 66%, Loss 0.686220]
# Iter 2500. [Val Acc 66%, Loss 0.684653]
# Iter 3000. [Val Acc 66%, Loss 0.683141]
# Iter 3500. [Val Acc 66%, Loss 0.681679]
# Iter 4000. [Val Acc 66%, Loss 0.680262]
# Iter 4500. [Val Acc 66%, Loss 0.678896]
# Iter 5000. [Val Acc 66%, Loss 0.677574]
# Iter 5500. [Val Acc 66%, Loss 0.676289]
# Iter 6000. [Val Acc 66%, Loss 0.675054]
# Iter 6500. [Val Acc 66%, Loss 0.673849]
# Iter 7000. [Val Acc 66%, Loss 0.672688]
# Iter 7500. [Val Acc 66%, Loss 0.671549]
# Iter 8000. [Val Acc 66%, Loss 0.670444]
# Iter 8500. [Val Acc 67%, Loss 0.669372]
# Iter 9000. [Val Acc 67%, Loss 0.668330]
# Iter 9500. [Val Acc 67%, Loss 0.667314]
# Iter 10000. [Val Acc 67%, Loss 0.666330]
# Iter 500. [Val Acc 65%, Loss 0.691313]
# Iter 1000. [Val Acc 66%, Loss 0.689549]
# Iter 1500. [Val Acc 66%, Loss 0.687856]
# Iter 2000. [Val Acc 66%, Loss 0.686221]
# Iter 2500. [Val Acc 66%, Loss 0.684649]
# Iter 3000. [Val Acc 66%, Loss 0.683136]
# Iter 3500. [Val Acc 66%, Loss 0.681671]
# Iter 4000. [Val Acc 66%, Loss 0.680264]
# Iter 4500. [Val Acc 66%, Loss 0.678898]
# Iter 5000. [Val Acc 66%, Loss 0.677573]
# Iter 5500. [Val Acc 66%, Loss 0.676294]
# Iter 6000. [Val Acc 66%, Loss 0.675054]
# Iter 6500. [Val Acc 66%, Loss 0.673850]
# Iter 7000. [Val Acc 66%, Loss 0.672683]
# Iter 7500. [Val Acc 66%, Loss 0.671550]
# Iter 8000. [Val Acc 66%, Loss 0.670449]
# Iter 8500. [Val Acc 67%, Loss 0.669379]
# Iter 9000. [Val Acc 67%, Loss 0.668332]
# Iter 9500. [Val Acc 67%, Loss 0.667317]
# Iter 10000. [Val Acc 67%, Loss 0.666328]
# Iter 500. [Val Acc 65%, Loss 0.691313]
# Iter 1000. [Val Acc 66%, Loss 0.689549]
# Iter 1500. [Val Acc 66%, Loss 0.687851]
# Iter 2000. [Val Acc 66%, Loss 0.686222]
# Iter 2500. [Val Acc 66%, Loss 0.684654]
# Iter 3000. [Val Acc 66%, Loss 0.683134]
# Iter 3500. [Val Acc 66%, Loss 0.681675]
# Iter 4000. [Val Acc 66%, Loss 0.680263]
# Iter 4500. [Val Acc 66%, Loss 0.678896]
# Iter 5000. [Val Acc 66%, Loss 0.677575]
# Iter 5500. [Val Acc 66%, Loss 0.676294]
# Iter 6000. [Val Acc 66%, Loss 0.675056]
# Iter 6500. [Val Acc 66%, Loss 0.673853]
# Iter 7000. [Val Acc 66%, Loss 0.672686]
# Iter 7500. [Val Acc 66%, Loss 0.671553]
# Iter 8000. [Val Acc 66%, Loss 0.670448]
# Iter 8500. [Val Acc 67%, Loss 0.669376]
# Iter 9000. [Val Acc 67%, Loss 0.668330]
# Iter 9500. [Val Acc 67%, Loss 0.667317]
# Iter 10000. [Val Acc 67%, Loss 0.666327]
# Iter 500. [Val Acc 66%, Loss 0.691312]
# Iter 1000. [Val Acc 66%, Loss 0.689549]
# Iter 1500. [Val Acc 66%, Loss 0.687856]
# Iter 2000. [Val Acc 66%, Loss 0.686224]
# Iter 2500. [Val Acc 66%, Loss 0.684650]
# Iter 3000. [Val Acc 66%, Loss 0.683139]
# Iter 3500. [Val Acc 66%, Loss 0.681674]
# Iter 4000. [Val Acc 66%, Loss 0.680262]
# Iter 4500. [Val Acc 66%, Loss 0.678897]
# Iter 5000. [Val Acc 66%, Loss 0.677575]
# Iter 5500. [Val Acc 66%, Loss 0.676292]
# Iter 6000. [Val Acc 66%, Loss 0.675053]
# Iter 6500. [Val Acc 66%, Loss 0.673853]
# Iter 7000. [Val Acc 66%, Loss 0.672685]
# Iter 7500. [Val Acc 66%, Loss 0.671553]
# Iter 8000. [Val Acc 66%, Loss 0.670449]
# Iter 8500. [Val Acc 67%, Loss 0.669378]
# Iter 9000. [Val Acc 67%, Loss 0.668333]
# Iter 9500. [Val Acc 67%, Loss 0.667318]
# Iter 10000. [Val Acc 67%, Loss 0.666328]
# Iter 500. [Val Acc 65%, Loss 0.691312]
# Iter 1000. [Val Acc 66%, Loss 0.689550]
# Iter 1500. [Val Acc 66%, Loss 0.687856]
# Iter 2000. [Val Acc 66%, Loss 0.686223]
# Iter 2500. [Val Acc 66%, Loss 0.684653]
# Iter 3000. [Val Acc 66%, Loss 0.683136]
# Iter 3500. [Val Acc 66%, Loss 0.681674]
# Iter 4000. [Val Acc 66%, Loss 0.680261]
# Iter 4500. [Val Acc 66%, Loss 0.678894]
# Iter 5000. [Val Acc 66%, Loss 0.677572]
# Iter 5500. [Val Acc 66%, Loss 0.676293]
# Iter 6000. [Val Acc 66%, Loss 0.675054]
# Iter 6500. [Val Acc 66%, Loss 0.673850]
# Iter 7000. [Val Acc 66%, Loss 0.672682]
# Iter 7500. [Val Acc 66%, Loss 0.671550]
# Iter 8000. [Val Acc 66%, Loss 0.670448]
# Iter 8500. [Val Acc 67%, Loss 0.669375]
# Iter 9000. [Val Acc 67%, Loss 0.668336]
# Iter 9500. [Val Acc 67%, Loss 0.667318]
# Iter 10000. [Val Acc 67%, Loss 0.666327]
# Iter 500. [Val Acc 66%, Loss 0.691314]
# Iter 1000. [Val Acc 66%, Loss 0.689550]
# Iter 1500. [Val Acc 66%, Loss 0.687854]
# Iter 2000. [Val Acc 66%, Loss 0.686223]
# Iter 2500. [Val Acc 66%, Loss 0.684651]
# Iter 3000. [Val Acc 66%, Loss 0.683136]
# Iter 3500. [Val Acc 66%, Loss 0.681674]
# Iter 4000. [Val Acc 66%, Loss 0.680260]
# Iter 4500. [Val Acc 66%, Loss 0.678895]
# Iter 5000. [Val Acc 66%, Loss 0.677573]
# Iter 5500. [Val Acc 66%, Loss 0.676295]
# Iter 6000. [Val Acc 66%, Loss 0.675054]
# Iter 6500. [Val Acc 66%, Loss 0.673854]
# Iter 7000. [Val Acc 66%, Loss 0.672684]
# Iter 7500. [Val Acc 66%, Loss 0.671550]
# Iter 8000. [Val Acc 66%, Loss 0.670450]
# Iter 8500. [Val Acc 67%, Loss 0.669376]
# Iter 9000. [Val Acc 67%, Loss 0.668335]
# Iter 9500. [Val Acc 67%, Loss 0.667317]
# Iter 10000. [Val Acc 67%, Loss 0.666327]
# Iter 500. [Val Acc 65%, Loss 0.691312]
# Iter 1000. [Val Acc 66%, Loss 0.689548]
# Iter 1500. [Val Acc 66%, Loss 0.687855]
# Iter 2000. [Val Acc 66%, Loss 0.686223]
# Iter 2500. [Val Acc 66%, Loss 0.684651]
# Iter 3000. [Val Acc 66%, Loss 0.683137]
# Iter 3500. [Val Acc 66%, Loss 0.681674]
# Iter 4000. [Val Acc 66%, Loss 0.680260]
# Iter 4500. [Val Acc 66%, Loss 0.678895]
# Iter 5000. [Val Acc 66%, Loss 0.677573]
# Iter 5500. [Val Acc 66%, Loss 0.676292]
# Iter 6000. [Val Acc 66%, Loss 0.675055]
# Iter 6500. [Val Acc 66%, Loss 0.673851]
# Iter 7000. [Val Acc 66%, Loss 0.672684]
# Iter 7500. [Val Acc 66%, Loss 0.671550]
# Iter 8000. [Val Acc 66%, Loss 0.670449]
# Iter 8500. [Val Acc 67%, Loss 0.669377]
# Iter 9000. [Val Acc 67%, Loss 0.668333]
# Iter 9500. [Val Acc 67%, Loss 0.667318]
# Iter 10000. [Val Acc 67%, Loss 0.666327]
# Iter 500. [Val Acc 65%, Loss 0.691313]
# Iter 1000. [Val Acc 66%, Loss 0.689552]
# Iter 1500. [Val Acc 66%, Loss 0.687857]
# Iter 2000. [Val Acc 66%, Loss 0.686224]
# Iter 2500. [Val Acc 66%, Loss 0.684652]
# Iter 3000. [Val Acc 66%, Loss 0.683136]
# Iter 3500. [Val Acc 66%, Loss 0.681675]
# Iter 4000. [Val Acc 66%, Loss 0.680262]
# Iter 4500. [Val Acc 66%, Loss 0.678895]
# Iter 5000. [Val Acc 66%, Loss 0.677575]
# Iter 5500. [Val Acc 66%, Loss 0.676293]
# Iter 6000. [Val Acc 66%, Loss 0.675054]
# Iter 6500. [Val Acc 66%, Loss 0.673852]
# Iter 7000. [Val Acc 66%, Loss 0.672684]
# Iter 7500. [Val Acc 66%, Loss 0.671550]
# Iter 8000. [Val Acc 66%, Loss 0.670449]
# Iter 8500. [Val Acc 67%, Loss 0.669377]
# Iter 9000. [Val Acc 67%, Loss 0.668335]
# Iter 9500. [Val Acc 67%, Loss 0.667318]
# Iter 10000. [Val Acc 67%, Loss 0.666329]
# Iter 500. [Val Acc 65%, Loss 0.691311]
# Iter 1000. [Val Acc 66%, Loss 0.689550]
# Iter 1500. [Val Acc 66%, Loss 0.687855]
# Iter 2000. [Val Acc 66%, Loss 0.686224]
# Iter 2500. [Val Acc 66%, Loss 0.684651]
# Iter 3000. [Val Acc 66%, Loss 0.683136]
# Iter 3500. [Val Acc 66%, Loss 0.681673]
# Iter 4000. [Val Acc 66%, Loss 0.680260]
# Iter 4500. [Val Acc 66%, Loss 0.678894]
# Iter 5000. [Val Acc 66%, Loss 0.677573]
# Iter 5500. [Val Acc 66%, Loss 0.676295]
# Iter 6000. [Val Acc 66%, Loss 0.675053]
# Iter 6500. [Val Acc 66%, Loss 0.673851]
# Iter 7000. [Val Acc 66%, Loss 0.672684]
# Iter 7500. [Val Acc 66%, Loss 0.671551]
# Iter 8000. [Val Acc 66%, Loss 0.670448]
# Iter 8500. [Val Acc 67%, Loss 0.669377]
# Iter 9000. [Val Acc 67%, Loss 0.668334]
# Iter 9500. [Val Acc 67%, Loss 0.667318]
# Iter 10000. [Val Acc 67%, Loss 0.666328]
# Iter 500. [Val Acc 65%, Loss 0.691312]
# Iter 1000. [Val Acc 66%, Loss 0.689551]
# Iter 1500. [Val Acc 66%, Loss 0.687854]
# Iter 2000. [Val Acc 66%, Loss 0.686223]
# Iter 2500. [Val Acc 66%, Loss 0.684652]
# Iter 3000. [Val Acc 66%, Loss 0.683137]
# Iter 3500. [Val Acc 66%, Loss 0.681674]
# Iter 4000. [Val Acc 66%, Loss 0.680260]
# Iter 4500. [Val Acc 66%, Loss 0.678894]
# Iter 5000. [Val Acc 66%, Loss 0.677573]
# Iter 5500. [Val Acc 66%, Loss 0.676293]
# Iter 6000. [Val Acc 66%, Loss 0.675053]
# Iter 6500. [Val Acc 66%, Loss 0.673850]
# Iter 7000. [Val Acc 66%, Loss 0.672682]
# Iter 7500. [Val Acc 66%, Loss 0.671549]
# Iter 8000. [Val Acc 66%, Loss 0.670448]
# Iter 8500. [Val Acc 67%, Loss 0.669376]
# Iter 9000. [Val Acc 67%, Loss 0.668332]
# Iter 9500. [Val Acc 67%, Loss 0.667317]
# Iter 10000. [Val Acc 67%, Loss 0.666327]
# Iter 500. [Val Acc 65%, Loss 0.691313]
# Iter 1000. [Val Acc 66%, Loss 0.689550]
# Iter 1500. [Val Acc 66%, Loss 0.687855]
# Iter 2000. [Val Acc 66%, Loss 0.686223]
# Iter 2500. [Val Acc 66%, Loss 0.684652]
# Iter 3000. [Val Acc 66%, Loss 0.683136]
# Iter 3500. [Val Acc 66%, Loss 0.681674]
# Iter 4000. [Val Acc 66%, Loss 0.680261]
# Iter 4500. [Val Acc 66%, Loss 0.678895]
# Iter 5000. [Val Acc 66%, Loss 0.677573]
# Iter 5500. [Val Acc 66%, Loss 0.676294]
# Iter 6000. [Val Acc 66%, Loss 0.675054]
# Iter 6500. [Val Acc 66%, Loss 0.673851]
# Iter 7000. [Val Acc 66%, Loss 0.672684]
# Iter 7500. [Val Acc 66%, Loss 0.671550]
# Iter 8000. [Val Acc 66%, Loss 0.670448]
# Iter 8500. [Val Acc 67%, Loss 0.669376]
# Iter 9000. [Val Acc 67%, Loss 0.668333]
# Iter 9500. [Val Acc 67%, Loss 0.667317]
# Iter 10000. [Val Acc 67%, Loss 0.666327]
# Iter 500. [Val Acc 65%, Loss 0.691311]
# Iter 1000. [Val Acc 66%, Loss 0.689549]
# Iter 1500. [Val Acc 66%, Loss 0.687855]
# Iter 2000. [Val Acc 66%, Loss 0.686224]
# Iter 2500. [Val Acc 66%, Loss 0.684652]
# Iter 3000. [Val Acc 66%, Loss 0.683137]
# Iter 3500. [Val Acc 66%, Loss 0.681675]
# Iter 4000. [Val Acc 66%, Loss 0.680262]
# Iter 4500. [Val Acc 66%, Loss 0.678896]
# Iter 5000. [Val Acc 66%, Loss 0.677573]
# Iter 5500. [Val Acc 66%, Loss 0.676293]
# Iter 6000. [Val Acc 66%, Loss 0.675053]
# Iter 6500. [Val Acc 66%, Loss 0.673850]
# Iter 7000. [Val Acc 66%, Loss 0.672683]
# Iter 7500. [Val Acc 66%, Loss 0.671549]
# Iter 8000. [Val Acc 66%, Loss 0.670447]
# Iter 8500. [Val Acc 67%, Loss 0.669376]
# Iter 9000. [Val Acc 67%, Loss 0.668333]
# Iter 9500. [Val Acc 67%, Loss 0.667316]
# Iter 10000. [Val Acc 67%, Loss 0.666327]
# Iter 500. [Val Acc 66%, Loss 0.689540]
# Iter 1000. [Val Acc 66%, Loss 0.686218]
# Iter 1500. [Val Acc 66%, Loss 0.683142]
# Iter 2000. [Val Acc 66%, Loss 0.680257]
# Iter 2500. [Val Acc 66%, Loss 0.677576]
# Iter 3000. [Val Acc 66%, Loss 0.675036]
# Iter 3500. [Val Acc 66%, Loss 0.672687]
# Iter 4000. [Val Acc 66%, Loss 0.670441]
# Iter 4500. [Val Acc 67%, Loss 0.668331]
# Iter 5000. [Val Acc 67%, Loss 0.666321]
# Iter 5500. [Val Acc 67%, Loss 0.664422]
# Iter 6000. [Val Acc 67%, Loss 0.662601]
# Iter 6500. [Val Acc 67%, Loss 0.660869]
# Iter 7000. [Val Acc 67%, Loss 0.659224]
# Iter 7500. [Val Acc 67%, Loss 0.657624]
# Iter 8000. [Val Acc 67%, Loss 0.656099]
# Iter 8500. [Val Acc 68%, Loss 0.654621]
# Iter 9000. [Val Acc 68%, Loss 0.653212]
# Iter 9500. [Val Acc 68%, Loss 0.651850]
# Iter 10000. [Val Acc 68%, Loss 0.650538]
# Iter 500. [Val Acc 66%, Loss 0.689542]
# Iter 1000. [Val Acc 66%, Loss 0.686220]
# Iter 1500. [Val Acc 66%, Loss 0.683137]
# Iter 2000. [Val Acc 66%, Loss 0.680266]
# Iter 2500. [Val Acc 66%, Loss 0.677574]
# Iter 3000. [Val Acc 66%, Loss 0.675053]
# Iter 3500. [Val Acc 66%, Loss 0.672677]
# Iter 4000. [Val Acc 66%, Loss 0.670456]
# Iter 4500. [Val Acc 67%, Loss 0.668333]
# Iter 5000. [Val Acc 67%, Loss 0.666324]
# Iter 5500. [Val Acc 67%, Loss 0.664415]
# Iter 6000. [Val Acc 67%, Loss 0.662608]
# Iter 6500. [Val Acc 67%, Loss 0.660863]
# Iter 7000. [Val Acc 67%, Loss 0.659208]
# Iter 7500. [Val Acc 67%, Loss 0.657619]
# Iter 8000. [Val Acc 67%, Loss 0.656094]
# Iter 8500. [Val Acc 68%, Loss 0.654623]
# Iter 9000. [Val Acc 68%, Loss 0.653214]
# Iter 9500. [Val Acc 68%, Loss 0.651854]
# Iter 10000. [Val Acc 68%, Loss 0.650539]
# Iter 500. [Val Acc 66%, Loss 0.689547]
# Iter 1000. [Val Acc 66%, Loss 0.686223]
# Iter 1500. [Val Acc 66%, Loss 0.683142]
# Iter 2000. [Val Acc 66%, Loss 0.680260]
# Iter 2500. [Val Acc 66%, Loss 0.677577]
# Iter 3000. [Val Acc 66%, Loss 0.675054]
# Iter 3500. [Val Acc 66%, Loss 0.672687]
# Iter 4000. [Val Acc 66%, Loss 0.670448]
# Iter 4500. [Val Acc 67%, Loss 0.668338]
# Iter 5000. [Val Acc 67%, Loss 0.666325]
# Iter 5500. [Val Acc 67%, Loss 0.664421]
# Iter 6000. [Val Acc 67%, Loss 0.662601]
# Iter 6500. [Val Acc 67%, Loss 0.660873]
# Iter 7000. [Val Acc 67%, Loss 0.659214]
# Iter 7500. [Val Acc 67%, Loss 0.657622]
# Iter 8000. [Val Acc 67%, Loss 0.656094]
# Iter 8500. [Val Acc 68%, Loss 0.654625]
# Iter 9000. [Val Acc 68%, Loss 0.653213]
# Iter 9500. [Val Acc 68%, Loss 0.651854]
# Iter 10000. [Val Acc 68%, Loss 0.650539]
# Iter 500. [Val Acc 66%, Loss 0.689550]
# Iter 1000. [Val Acc 66%, Loss 0.686224]
# Iter 1500. [Val Acc 66%, Loss 0.683142]
# Iter 2000. [Val Acc 66%, Loss 0.680263]
# Iter 2500. [Val Acc 66%, Loss 0.677570]
# Iter 3000. [Val Acc 66%, Loss 0.675051]
# Iter 3500. [Val Acc 66%, Loss 0.672683]
# Iter 4000. [Val Acc 66%, Loss 0.670449]
# Iter 4500. [Val Acc 67%, Loss 0.668332]
# Iter 5000. [Val Acc 67%, Loss 0.666326]
# Iter 5500. [Val Acc 67%, Loss 0.664422]
# Iter 6000. [Val Acc 67%, Loss 0.662605]
# Iter 6500. [Val Acc 67%, Loss 0.660870]
# Iter 7000. [Val Acc 67%, Loss 0.659211]
# Iter 7500. [Val Acc 67%, Loss 0.657618]
# Iter 8000. [Val Acc 67%, Loss 0.656093]
# Iter 8500. [Val Acc 68%, Loss 0.654628]
# Iter 9000. [Val Acc 68%, Loss 0.653211]
# Iter 9500. [Val Acc 68%, Loss 0.651852]
# Iter 10000. [Val Acc 68%, Loss 0.650543]
# Iter 500. [Val Acc 66%, Loss 0.689551]
# Iter 1000. [Val Acc 66%, Loss 0.686223]
# Iter 1500. [Val Acc 66%, Loss 0.683135]
# Iter 2000. [Val Acc 66%, Loss 0.680262]
# Iter 2500. [Val Acc 66%, Loss 0.677574]
# Iter 3000. [Val Acc 66%, Loss 0.675056]
# Iter 3500. [Val Acc 66%, Loss 0.672680]
# Iter 4000. [Val Acc 66%, Loss 0.670448]
# Iter 4500. [Val Acc 67%, Loss 0.668335]
# Iter 5000. [Val Acc 67%, Loss 0.666326]
# Iter 5500. [Val Acc 67%, Loss 0.664418]
# Iter 6000. [Val Acc 67%, Loss 0.662603]
# Iter 6500. [Val Acc 67%, Loss 0.660869]
# Iter 7000. [Val Acc 67%, Loss 0.659212]
# Iter 7500. [Val Acc 67%, Loss 0.657619]
# Iter 8000. [Val Acc 67%, Loss 0.656094]
# Iter 8500. [Val Acc 68%, Loss 0.654624]
# Iter 9000. [Val Acc 68%, Loss 0.653211]
# Iter 9500. [Val Acc 68%, Loss 0.651850]
# Iter 10000. [Val Acc 68%, Loss 0.650540]
# Iter 500. [Val Acc 66%, Loss 0.689555]
# Iter 1000. [Val Acc 66%, Loss 0.686217]
# Iter 1500. [Val Acc 66%, Loss 0.683134]
# Iter 2000. [Val Acc 66%, Loss 0.680259]
# Iter 2500. [Val Acc 66%, Loss 0.677574]
# Iter 3000. [Val Acc 66%, Loss 0.675053]
# Iter 3500. [Val Acc 66%, Loss 0.672681]
# Iter 4000. [Val Acc 66%, Loss 0.670449]
# Iter 4500. [Val Acc 67%, Loss 0.668333]
# Iter 5000. [Val Acc 67%, Loss 0.666325]
# Iter 5500. [Val Acc 67%, Loss 0.664421]
# Iter 6000. [Val Acc 67%, Loss 0.662602]
# Iter 6500. [Val Acc 67%, Loss 0.660869]
# Iter 7000. [Val Acc 67%, Loss 0.659211]
# Iter 7500. [Val Acc 67%, Loss 0.657621]
# Iter 8000. [Val Acc 67%, Loss 0.656091]
# Iter 8500. [Val Acc 68%, Loss 0.654627]
# Iter 9000. [Val Acc 68%, Loss 0.653213]
# Iter 9500. [Val Acc 68%, Loss 0.651854]
# Iter 10000. [Val Acc 68%, Loss 0.650540]
# Iter 500. [Val Acc 66%, Loss 0.689547]
# Iter 1000. [Val Acc 66%, Loss 0.686227]
# Iter 1500. [Val Acc 66%, Loss 0.683136]
# Iter 2000. [Val Acc 66%, Loss 0.680261]
# Iter 2500. [Val Acc 66%, Loss 0.677575]
# Iter 3000. [Val Acc 66%, Loss 0.675054]
# Iter 3500. [Val Acc 66%, Loss 0.672686]
# Iter 4000. [Val Acc 66%, Loss 0.670449]
# Iter 4500. [Val Acc 67%, Loss 0.668333]
# Iter 5000. [Val Acc 67%, Loss 0.666329]
# Iter 5500. [Val Acc 67%, Loss 0.664421]
# Iter 6000. [Val Acc 67%, Loss 0.662602]
# Iter 6500. [Val Acc 67%, Loss 0.660869]
# Iter 7000. [Val Acc 67%, Loss 0.659211]
# Iter 7500. [Val Acc 67%, Loss 0.657620]
# Iter 8000. [Val Acc 67%, Loss 0.656093]
# Iter 8500. [Val Acc 68%, Loss 0.654627]
# Iter 9000. [Val Acc 68%, Loss 0.653215]
# Iter 9500. [Val Acc 68%, Loss 0.651854]
# Iter 10000. [Val Acc 68%, Loss 0.650540]
# Iter 500. [Val Acc 66%, Loss 0.689550]
# Iter 1000. [Val Acc 66%, Loss 0.686223]
# Iter 1500. [Val Acc 66%, Loss 0.683136]
# Iter 2000. [Val Acc 66%, Loss 0.680260]
# Iter 2500. [Val Acc 66%, Loss 0.677571]
# Iter 3000. [Val Acc 66%, Loss 0.675054]
# Iter 3500. [Val Acc 66%, Loss 0.672682]
# Iter 4000. [Val Acc 66%, Loss 0.670447]
# Iter 4500. [Val Acc 67%, Loss 0.668331]
# Iter 5000. [Val Acc 67%, Loss 0.666326]
# Iter 5500. [Val Acc 67%, Loss 0.664419]
# Iter 6000. [Val Acc 67%, Loss 0.662601]
# Iter 6500. [Val Acc 67%, Loss 0.660868]
# Iter 7000. [Val Acc 67%, Loss 0.659209]
# Iter 7500. [Val Acc 67%, Loss 0.657619]
# Iter 8000. [Val Acc 67%, Loss 0.656094]
# Iter 8500. [Val Acc 68%, Loss 0.654627]
# Iter 9000. [Val Acc 68%, Loss 0.653213]
# Iter 9500. [Val Acc 68%, Loss 0.651853]
# Iter 10000. [Val Acc 68%, Loss 0.650540]
# Iter 500. [Val Acc 66%, Loss 0.689552]
# Iter 1000. [Val Acc 66%, Loss 0.686224]
# Iter 1500. [Val Acc 66%, Loss 0.683136]
# Iter 2000. [Val Acc 66%, Loss 0.680263]
# Iter 2500. [Val Acc 66%, Loss 0.677573]
# Iter 3000. [Val Acc 66%, Loss 0.675053]
# Iter 3500. [Val Acc 66%, Loss 0.672685]
# Iter 4000. [Val Acc 66%, Loss 0.670447]
# Iter 4500. [Val Acc 67%, Loss 0.668332]
# Iter 5000. [Val Acc 67%, Loss 0.666326]
# Iter 5500. [Val Acc 67%, Loss 0.664421]
# Iter 6000. [Val Acc 67%, Loss 0.662603]
# Iter 6500. [Val Acc 67%, Loss 0.660867]
# Iter 7000. [Val Acc 67%, Loss 0.659208]
# Iter 7500. [Val Acc 67%, Loss 0.657620]
# Iter 8000. [Val Acc 67%, Loss 0.656093]
# Iter 8500. [Val Acc 68%, Loss 0.654626]
# Iter 9000. [Val Acc 68%, Loss 0.653214]
# Iter 9500. [Val Acc 68%, Loss 0.651852]
# Iter 10000. [Val Acc 68%, Loss 0.650539]
# Iter 500. [Val Acc 66%, Loss 0.689550]
# Iter 1000. [Val Acc 66%, Loss 0.686223]
# Iter 1500. [Val Acc 66%, Loss 0.683138]
# Iter 2000. [Val Acc 66%, Loss 0.680261]
# Iter 2500. [Val Acc 66%, Loss 0.677574]
# Iter 3000. [Val Acc 66%, Loss 0.675052]
# Iter 3500. [Val Acc 66%, Loss 0.672681]
# Iter 4000. [Val Acc 66%, Loss 0.670448]
# Iter 4500. [Val Acc 67%, Loss 0.668332]
# Iter 5000. [Val Acc 67%, Loss 0.666327]
# Iter 5500. [Val Acc 67%, Loss 0.664421]
# Iter 6000. [Val Acc 67%, Loss 0.662605]
# Iter 6500. [Val Acc 67%, Loss 0.660870]
# Iter 7000. [Val Acc 67%, Loss 0.659210]
# Iter 7500. [Val Acc 67%, Loss 0.657618]
# Iter 8000. [Val Acc 67%, Loss 0.656093]
# Iter 8500. [Val Acc 68%, Loss 0.654625]
# Iter 9000. [Val Acc 68%, Loss 0.653214]
# Iter 9500. [Val Acc 68%, Loss 0.651853]
# Iter 10000. [Val Acc 68%, Loss 0.650539]
# Iter 500. [Val Acc 66%, Loss 0.689549]
# Iter 1000. [Val Acc 66%, Loss 0.686222]
# Iter 1500. [Val Acc 66%, Loss 0.683135]
# Iter 2000. [Val Acc 66%, Loss 0.680259]
# Iter 2500. [Val Acc 66%, Loss 0.677573]
# Iter 3000. [Val Acc 66%, Loss 0.675053]
# Iter 3500. [Val Acc 66%, Loss 0.672683]
# Iter 4000. [Val Acc 66%, Loss 0.670448]
# Iter 4500. [Val Acc 67%, Loss 0.668333]
# Iter 5000. [Val Acc 67%, Loss 0.666328]
# Iter 5500. [Val Acc 67%, Loss 0.664421]
# Iter 6000. [Val Acc 67%, Loss 0.662604]
# Iter 6500. [Val Acc 67%, Loss 0.660869]
# Iter 7000. [Val Acc 67%, Loss 0.659209]
# Iter 7500. [Val Acc 67%, Loss 0.657620]
# Iter 8000. [Val Acc 67%, Loss 0.656093]
# Iter 8500. [Val Acc 68%, Loss 0.654626]
# Iter 9000. [Val Acc 68%, Loss 0.653214]
# Iter 9500. [Val Acc 68%, Loss 0.651854]
# Iter 10000. [Val Acc 68%, Loss 0.650540]
# Iter 500. [Val Acc 66%, Loss 0.689547]
# Iter 1000. [Val Acc 66%, Loss 0.686224]
# Iter 1500. [Val Acc 66%, Loss 0.683136]
# Iter 2000. [Val Acc 66%, Loss 0.680261]
# Iter 2500. [Val Acc 66%, Loss 0.677575]
# Iter 3000. [Val Acc 66%, Loss 0.675053]
# Iter 3500. [Val Acc 66%, Loss 0.672682]
# Iter 4000. [Val Acc 66%, Loss 0.670447]
# Iter 4500. [Val Acc 67%, Loss 0.668334]
# Iter 5000. [Val Acc 67%, Loss 0.666326]
# Iter 5500. [Val Acc 67%, Loss 0.664421]
# Iter 6000. [Val Acc 67%, Loss 0.662605]
# Iter 6500. [Val Acc 67%, Loss 0.660869]
# Iter 7000. [Val Acc 67%, Loss 0.659210]
# Iter 7500. [Val Acc 67%, Loss 0.657621]
# Iter 8000. [Val Acc 67%, Loss 0.656094]
# Iter 8500. [Val Acc 68%, Loss 0.654627]
# Iter 9000. [Val Acc 68%, Loss 0.653214]
# Iter 9500. [Val Acc 68%, Loss 0.651854]
# Iter 10000. [Val Acc 68%, Loss 0.650540]
# Iter 500. [Val Acc 66%, Loss 0.677580]
# Iter 1000. [Val Acc 67%, Loss 0.666336]
# Iter 1500. [Val Acc 67%, Loss 0.657650]
# Iter 2000. [Val Acc 68%, Loss 0.650552]
# Iter 2500. [Val Acc 68%, Loss 0.644576]
# Iter 3000. [Val Acc 69%, Loss 0.639468]
# Iter 3500. [Val Acc 69%, Loss 0.634972]
# Iter 4000. [Val Acc 69%, Loss 0.631039]
# Iter 4500. [Val Acc 69%, Loss 0.627498]
# Iter 5000. [Val Acc 69%, Loss 0.624319]
# Iter 5500. [Val Acc 70%, Loss 0.621432]
# Iter 6000. [Val Acc 70%, Loss 0.618813]
# Iter 6500. [Val Acc 70%, Loss 0.616367]
# Iter 7000. [Val Acc 70%, Loss 0.614116]
# Iter 7500. [Val Acc 70%, Loss 0.612068]
# Iter 8000. [Val Acc 70%, Loss 0.610155]
# Iter 8500. [Val Acc 70%, Loss 0.608366]
# Iter 9000. [Val Acc 71%, Loss 0.606680]
# Iter 9500. [Val Acc 71%, Loss 0.605116]
# Iter 10000. [Val Acc 71%, Loss 0.603630]
# Iter 500. [Val Acc 66%, Loss 0.677623]
# Iter 1000. [Val Acc 67%, Loss 0.666339]
# Iter 1500. [Val Acc 67%, Loss 0.657632]
# Iter 2000. [Val Acc 68%, Loss 0.650552]
# Iter 2500. [Val Acc 68%, Loss 0.644581]
# Iter 3000. [Val Acc 69%, Loss 0.639465]
# Iter 3500. [Val Acc 69%, Loss 0.634991]
# Iter 4000. [Val Acc 69%, Loss 0.631040]
# Iter 4500. [Val Acc 69%, Loss 0.627506]
# Iter 5000. [Val Acc 70%, Loss 0.624316]
# Iter 5500. [Val Acc 70%, Loss 0.621434]
# Iter 6000. [Val Acc 70%, Loss 0.618788]
# Iter 6500. [Val Acc 70%, Loss 0.616364]
# Iter 7000. [Val Acc 70%, Loss 0.614132]
# Iter 7500. [Val Acc 70%, Loss 0.612068]
# Iter 8000. [Val Acc 70%, Loss 0.610150]
# Iter 8500. [Val Acc 70%, Loss 0.608356]
# Iter 9000. [Val Acc 71%, Loss 0.606682]
# Iter 9500. [Val Acc 71%, Loss 0.605105]
# Iter 10000. [Val Acc 71%, Loss 0.603626]
# Iter 500. [Val Acc 66%, Loss 0.677579]
# Iter 1000. [Val Acc 67%, Loss 0.666323]
# Iter 1500. [Val Acc 67%, Loss 0.657601]
# Iter 2000. [Val Acc 68%, Loss 0.650527]
# Iter 2500. [Val Acc 68%, Loss 0.644587]
# Iter 3000. [Val Acc 69%, Loss 0.639479]
# Iter 3500. [Val Acc 69%, Loss 0.634993]
# Iter 4000. [Val Acc 69%, Loss 0.631048]
# Iter 4500. [Val Acc 69%, Loss 0.627506]
# Iter 5000. [Val Acc 70%, Loss 0.624318]
# Iter 5500. [Val Acc 70%, Loss 0.621426]
# Iter 6000. [Val Acc 70%, Loss 0.618792]
# Iter 6500. [Val Acc 70%, Loss 0.616366]
# Iter 7000. [Val Acc 70%, Loss 0.614138]
# Iter 7500. [Val Acc 70%, Loss 0.612070]
# Iter 8000. [Val Acc 70%, Loss 0.610149]
# Iter 8500. [Val Acc 70%, Loss 0.608358]
# Iter 9000. [Val Acc 71%, Loss 0.606675]
# Iter 9500. [Val Acc 71%, Loss 0.605114]
# Iter 10000. [Val Acc 71%, Loss 0.603629]
# Iter 500. [Val Acc 66%, Loss 0.677587]
# Iter 1000. [Val Acc 67%, Loss 0.666327]
# Iter 1500. [Val Acc 67%, Loss 0.657621]
# Iter 2000. [Val Acc 68%, Loss 0.650537]
# Iter 2500. [Val Acc 68%, Loss 0.644586]
# Iter 3000. [Val Acc 68%, Loss 0.639471]
# Iter 3500. [Val Acc 69%, Loss 0.635001]
# Iter 4000. [Val Acc 69%, Loss 0.631045]
# Iter 4500. [Val Acc 69%, Loss 0.627508]
# Iter 5000. [Val Acc 69%, Loss 0.624321]
# Iter 5500. [Val Acc 70%, Loss 0.621428]
# Iter 6000. [Val Acc 70%, Loss 0.618794]
# Iter 6500. [Val Acc 70%, Loss 0.616371]
# Iter 7000. [Val Acc 70%, Loss 0.614136]
# Iter 7500. [Val Acc 70%, Loss 0.612071]
# Iter 8000. [Val Acc 70%, Loss 0.610150]
# Iter 8500. [Val Acc 70%, Loss 0.608356]
# Iter 9000. [Val Acc 71%, Loss 0.606680]
# Iter 9500. [Val Acc 71%, Loss 0.605106]
# Iter 10000. [Val Acc 71%, Loss 0.603627]
# Iter 500. [Val Acc 66%, Loss 0.677578]
# Iter 1000. [Val Acc 67%, Loss 0.666316]
# Iter 1500. [Val Acc 67%, Loss 0.657609]
# Iter 2000. [Val Acc 68%, Loss 0.650538]
# Iter 2500. [Val Acc 68%, Loss 0.644585]
# Iter 3000. [Val Acc 69%, Loss 0.639472]
# Iter 3500. [Val Acc 69%, Loss 0.634995]
# Iter 4000. [Val Acc 69%, Loss 0.631038]
# Iter 4500. [Val Acc 69%, Loss 0.627510]
# Iter 5000. [Val Acc 70%, Loss 0.624318]
# Iter 5500. [Val Acc 70%, Loss 0.621428]
# Iter 6000. [Val Acc 70%, Loss 0.618792]
# Iter 6500. [Val Acc 70%, Loss 0.616369]
# Iter 7000. [Val Acc 70%, Loss 0.614137]
# Iter 7500. [Val Acc 70%, Loss 0.612070]
# Iter 8000. [Val Acc 70%, Loss 0.610147]
# Iter 8500. [Val Acc 70%, Loss 0.608358]
# Iter 9000. [Val Acc 71%, Loss 0.606680]
# Iter 9500. [Val Acc 71%, Loss 0.605106]
# Iter 10000. [Val Acc 71%, Loss 0.603629]
# Iter 500. [Val Acc 66%, Loss 0.677587]
# Iter 1000. [Val Acc 67%, Loss 0.666339]
# Iter 1500. [Val Acc 67%, Loss 0.657619]
# Iter 2000. [Val Acc 68%, Loss 0.650536]
# Iter 2500. [Val Acc 68%, Loss 0.644588]
# Iter 3000. [Val Acc 69%, Loss 0.639470]
# Iter 3500. [Val Acc 69%, Loss 0.634998]
# Iter 4000. [Val Acc 69%, Loss 0.631043]
# Iter 4500. [Val Acc 69%, Loss 0.627505]
# Iter 5000. [Val Acc 70%, Loss 0.624320]
# Iter 5500. [Val Acc 70%, Loss 0.621428]
# Iter 6000. [Val Acc 70%, Loss 0.618789]
# Iter 6500. [Val Acc 70%, Loss 0.616369]
# Iter 7000. [Val Acc 70%, Loss 0.614135]
# Iter 7500. [Val Acc 70%, Loss 0.612069]
# Iter 8000. [Val Acc 70%, Loss 0.610147]
# Iter 8500. [Val Acc 70%, Loss 0.608357]
# Iter 9000. [Val Acc 71%, Loss 0.606680]
# Iter 9500. [Val Acc 71%, Loss 0.605108]
# Iter 10000. [Val Acc 71%, Loss 0.603628]
# Iter 500. [Val Acc 66%, Loss 0.677576]
# Iter 1000. [Val Acc 67%, Loss 0.666322]
# Iter 1500. [Val Acc 67%, Loss 0.657612]
# Iter 2000. [Val Acc 68%, Loss 0.650539]
# Iter 2500. [Val Acc 68%, Loss 0.644584]
# Iter 3000. [Val Acc 69%, Loss 0.639473]
# Iter 3500. [Val Acc 69%, Loss 0.635001]
# Iter 4000. [Val Acc 69%, Loss 0.631044]
# Iter 4500. [Val Acc 69%, Loss 0.627503]
# Iter 5000. [Val Acc 70%, Loss 0.624317]
# Iter 5500. [Val Acc 70%, Loss 0.621427]
# Iter 6000. [Val Acc 70%, Loss 0.618786]
# Iter 6500. [Val Acc 70%, Loss 0.616368]
# Iter 7000. [Val Acc 70%, Loss 0.614134]
# Iter 7500. [Val Acc 70%, Loss 0.612066]
# Iter 8000. [Val Acc 70%, Loss 0.610147]
# Iter 8500. [Val Acc 70%, Loss 0.608355]
# Iter 9000. [Val Acc 71%, Loss 0.606680]
# Iter 9500. [Val Acc 71%, Loss 0.605104]
# Iter 10000. [Val Acc 71%, Loss 0.603626]
# Iter 500. [Val Acc 66%, Loss 0.677568]
# Iter 1000. [Val Acc 67%, Loss 0.666327]
# Iter 1500. [Val Acc 67%, Loss 0.657618]
# Iter 2000. [Val Acc 68%, Loss 0.650537]
# Iter 2500. [Val Acc 68%, Loss 0.644584]
# Iter 3000. [Val Acc 69%, Loss 0.639469]
# Iter 3500. [Val Acc 69%, Loss 0.634999]
# Iter 4000. [Val Acc 69%, Loss 0.631042]
# Iter 4500. [Val Acc 69%, Loss 0.627504]
# Iter 5000. [Val Acc 69%, Loss 0.624320]
# Iter 5500. [Val Acc 70%, Loss 0.621429]
# Iter 6000. [Val Acc 70%, Loss 0.618791]
# Iter 6500. [Val Acc 70%, Loss 0.616367]
# Iter 7000. [Val Acc 70%, Loss 0.614135]
# Iter 7500. [Val Acc 70%, Loss 0.612067]
# Iter 8000. [Val Acc 70%, Loss 0.610151]
# Iter 8500. [Val Acc 70%, Loss 0.608356]
# Iter 9000. [Val Acc 71%, Loss 0.606681]
# Iter 9500. [Val Acc 71%, Loss 0.605107]
# Iter 10000. [Val Acc 71%, Loss 0.603627]
# Iter 500. [Val Acc 66%, Loss 0.677582]
# Iter 1000. [Val Acc 67%, Loss 0.666325]
# Iter 1500. [Val Acc 67%, Loss 0.657609]
# Iter 2000. [Val Acc 68%, Loss 0.650538]
# Iter 2500. [Val Acc 68%, Loss 0.644589]
# Iter 3000. [Val Acc 69%, Loss 0.639471]
# Iter 3500. [Val Acc 69%, Loss 0.635001]
# Iter 4000. [Val Acc 69%, Loss 0.631044]
# Iter 4500. [Val Acc 69%, Loss 0.627505]
# Iter 5000. [Val Acc 69%, Loss 0.624322]
# Iter 5500. [Val Acc 70%, Loss 0.621431]
# Iter 6000. [Val Acc 70%, Loss 0.618793]
# Iter 6500. [Val Acc 70%, Loss 0.616371]
# Iter 7000. [Val Acc 70%, Loss 0.614138]
# Iter 7500. [Val Acc 70%, Loss 0.612071]
# Iter 8000. [Val Acc 70%, Loss 0.610150]
# Iter 8500. [Val Acc 70%, Loss 0.608357]
# Iter 9000. [Val Acc 71%, Loss 0.606682]
# Iter 9500. [Val Acc 71%, Loss 0.605110]
# Iter 10000. [Val Acc 71%, Loss 0.603629]
# Iter 500. [Val Acc 66%, Loss 0.677570]
# Iter 1000. [Val Acc 67%, Loss 0.666322]
# Iter 1500. [Val Acc 67%, Loss 0.657621]
# Iter 2000. [Val Acc 68%, Loss 0.650538]
# Iter 2500. [Val Acc 68%, Loss 0.644585]
# Iter 3000. [Val Acc 69%, Loss 0.639471]
# Iter 3500. [Val Acc 69%, Loss 0.634998]
# Iter 4000. [Val Acc 69%, Loss 0.631040]
# Iter 4500. [Val Acc 69%, Loss 0.627505]
# Iter 5000. [Val Acc 69%, Loss 0.624318]
# Iter 5500. [Val Acc 70%, Loss 0.621427]
# Iter 6000. [Val Acc 70%, Loss 0.618790]
# Iter 6500. [Val Acc 70%, Loss 0.616366]
# Iter 7000. [Val Acc 70%, Loss 0.614137]
# Iter 7500. [Val Acc 70%, Loss 0.612068]
# Iter 8000. [Val Acc 70%, Loss 0.610149]
# Iter 8500. [Val Acc 70%, Loss 0.608356]
# Iter 9000. [Val Acc 71%, Loss 0.606680]
# Iter 9500. [Val Acc 71%, Loss 0.605108]
# Iter 10000. [Val Acc 71%, Loss 0.603627]
# Iter 500. [Val Acc 66%, Loss 0.677565]
# Iter 1000. [Val Acc 67%, Loss 0.666323]
# Iter 1500. [Val Acc 67%, Loss 0.657618]
# Iter 2000. [Val Acc 68%, Loss 0.650537]
# Iter 2500. [Val Acc 68%, Loss 0.644588]
# Iter 3000. [Val Acc 69%, Loss 0.639471]
# Iter 3500. [Val Acc 69%, Loss 0.635000]
# Iter 4000. [Val Acc 69%, Loss 0.631041]
# Iter 4500. [Val Acc 69%, Loss 0.627505]
# Iter 5000. [Val Acc 69%, Loss 0.624319]
# Iter 5500. [Val Acc 70%, Loss 0.621426]
# Iter 6000. [Val Acc 70%, Loss 0.618789]
# Iter 6500. [Val Acc 70%, Loss 0.616367]
# Iter 7000. [Val Acc 70%, Loss 0.614136]
# Iter 7500. [Val Acc 70%, Loss 0.612069]
# Iter 8000. [Val Acc 70%, Loss 0.610148]
# Iter 8500. [Val Acc 70%, Loss 0.608356]
# Iter 9000. [Val Acc 71%, Loss 0.606680]
# Iter 9500. [Val Acc 71%, Loss 0.605107]
# Iter 10000. [Val Acc 71%, Loss 0.603628]
# Iter 500. [Val Acc 66%, Loss 0.677576]
# Iter 1000. [Val Acc 67%, Loss 0.666328]
# Iter 1500. [Val Acc 67%, Loss 0.657617]
# Iter 2000. [Val Acc 68%, Loss 0.650540]
# Iter 2500. [Val Acc 68%, Loss 0.644588]
# Iter 3000. [Val Acc 69%, Loss 0.639474]
# Iter 3500. [Val Acc 69%, Loss 0.635002]
# Iter 4000. [Val Acc 69%, Loss 0.631045]
# Iter 4500. [Val Acc 69%, Loss 0.627510]
# Iter 5000. [Val Acc 70%, Loss 0.624322]
# Iter 5500. [Val Acc 70%, Loss 0.621433]
# Iter 6000. [Val Acc 70%, Loss 0.618792]
# Iter 6500. [Val Acc 70%, Loss 0.616370]
# Iter 7000. [Val Acc 70%, Loss 0.614137]
# Iter 7500. [Val Acc 70%, Loss 0.612070]
# Iter 8000. [Val Acc 70%, Loss 0.610150]
# Iter 8500. [Val Acc 70%, Loss 0.608359]
# Iter 9000. [Val Acc 71%, Loss 0.606681]
# Iter 9500. [Val Acc 71%, Loss 0.605108]
# Iter 10000. [Val Acc 71%, Loss 0.603630]
# Iter 500. [Val Acc 67%, Loss 0.666229]
# Iter 1000. [Val Acc 68%, Loss 0.650534]
# Iter 1500. [Val Acc 69%, Loss 0.639469]
# Iter 2000. [Val Acc 69%, Loss 0.631055]
# Iter 2500. [Val Acc 70%, Loss 0.624332]
# Iter 3000. [Val Acc 70%, Loss 0.618806]
# Iter 3500. [Val Acc 70%, Loss 0.614132]
# Iter 4000. [Val Acc 70%, Loss 0.610157]
# Iter 4500. [Val Acc 71%, Loss 0.606666]
# Iter 5000. [Val Acc 71%, Loss 0.603627]
# Iter 5500. [Val Acc 71%, Loss 0.600934]
# Iter 6000. [Val Acc 71%, Loss 0.598474]
# Iter 6500. [Val Acc 71%, Loss 0.596279]
# Iter 7000. [Val Acc 71%, Loss 0.594253]
# Iter 7500. [Val Acc 71%, Loss 0.592445]
# Iter 8000. [Val Acc 71%, Loss 0.590752]
# Iter 8500. [Val Acc 72%, Loss 0.589192]
# Iter 9000. [Val Acc 72%, Loss 0.587759]
# Iter 9500. [Val Acc 72%, Loss 0.586417]
# Iter 10000. [Val Acc 72%, Loss 0.585172]
# Iter 500. [Val Acc 67%, Loss 0.666377]
# Iter 1000. [Val Acc 68%, Loss 0.650560]
# Iter 1500. [Val Acc 68%, Loss 0.639469]
# Iter 2000. [Val Acc 69%, Loss 0.631067]
# Iter 2500. [Val Acc 69%, Loss 0.624316]
# Iter 3000. [Val Acc 70%, Loss 0.618790]
# Iter 3500. [Val Acc 70%, Loss 0.614137]
# Iter 4000. [Val Acc 70%, Loss 0.610140]
# Iter 4500. [Val Acc 71%, Loss 0.606680]
# Iter 5000. [Val Acc 71%, Loss 0.603621]
# Iter 5500. [Val Acc 71%, Loss 0.600907]
# Iter 6000. [Val Acc 71%, Loss 0.598471]
# Iter 6500. [Val Acc 71%, Loss 0.596267]
# Iter 7000. [Val Acc 71%, Loss 0.594272]
# Iter 7500. [Val Acc 71%, Loss 0.592435]
# Iter 8000. [Val Acc 71%, Loss 0.590754]
# Iter 8500. [Val Acc 72%, Loss 0.589189]
# Iter 9000. [Val Acc 72%, Loss 0.587759]
# Iter 9500. [Val Acc 72%, Loss 0.586420]
# Iter 10000. [Val Acc 72%, Loss 0.585171]
# Iter 500. [Val Acc 67%, Loss 0.666287]
# Iter 1000. [Val Acc 68%, Loss 0.650520]
# Iter 1500. [Val Acc 68%, Loss 0.639473]
# Iter 2000. [Val Acc 69%, Loss 0.631051]
# Iter 2500. [Val Acc 70%, Loss 0.624317]
# Iter 3000. [Val Acc 70%, Loss 0.618783]
# Iter 3500. [Val Acc 70%, Loss 0.614132]
# Iter 4000. [Val Acc 70%, Loss 0.610139]
# Iter 4500. [Val Acc 71%, Loss 0.606681]
# Iter 5000. [Val Acc 71%, Loss 0.603635]
# Iter 5500. [Val Acc 71%, Loss 0.600910]
# Iter 6000. [Val Acc 71%, Loss 0.598473]
# Iter 6500. [Val Acc 71%, Loss 0.596262]
# Iter 7000. [Val Acc 71%, Loss 0.594267]
# Iter 7500. [Val Acc 71%, Loss 0.592439]
# Iter 8000. [Val Acc 71%, Loss 0.590751]
# Iter 8500. [Val Acc 72%, Loss 0.589198]
# Iter 9000. [Val Acc 72%, Loss 0.587757]
# Iter 9500. [Val Acc 72%, Loss 0.586421]
# Iter 10000. [Val Acc 72%, Loss 0.585171]
# Iter 500. [Val Acc 67%, Loss 0.666324]
# Iter 1000. [Val Acc 68%, Loss 0.650540]
# Iter 1500. [Val Acc 69%, Loss 0.639469]
# Iter 2000. [Val Acc 69%, Loss 0.631046]
# Iter 2500. [Val Acc 70%, Loss 0.624326]
# Iter 3000. [Val Acc 70%, Loss 0.618784]
# Iter 3500. [Val Acc 70%, Loss 0.614134]
# Iter 4000. [Val Acc 70%, Loss 0.610146]
# Iter 4500. [Val Acc 71%, Loss 0.606678]
# Iter 5000. [Val Acc 71%, Loss 0.603620]
# Iter 5500. [Val Acc 71%, Loss 0.600917]
# Iter 6000. [Val Acc 71%, Loss 0.598473]
# Iter 6500. [Val Acc 71%, Loss 0.596271]
# Iter 7000. [Val Acc 71%, Loss 0.594269]
# Iter 7500. [Val Acc 71%, Loss 0.592435]
# Iter 8000. [Val Acc 71%, Loss 0.590751]
# Iter 8500. [Val Acc 72%, Loss 0.589203]
# Iter 9000. [Val Acc 72%, Loss 0.587756]
# Iter 9500. [Val Acc 72%, Loss 0.586419]
# Iter 10000. [Val Acc 72%, Loss 0.585176]
# Iter 500. [Val Acc 67%, Loss 0.666317]
# Iter 1000. [Val Acc 68%, Loss 0.650530]
# Iter 1500. [Val Acc 69%, Loss 0.639470]
# Iter 2000. [Val Acc 69%, Loss 0.631049]
# Iter 2500. [Val Acc 70%, Loss 0.624314]
# Iter 3000. [Val Acc 70%, Loss 0.618785]
# Iter 3500. [Val Acc 70%, Loss 0.614133]
# Iter 4000. [Val Acc 70%, Loss 0.610154]
# Iter 4500. [Val Acc 71%, Loss 0.606682]
# Iter 5000. [Val Acc 71%, Loss 0.603631]
# Iter 5500. [Val Acc 71%, Loss 0.600913]
# Iter 6000. [Val Acc 71%, Loss 0.598475]
# Iter 6500. [Val Acc 71%, Loss 0.596271]
# Iter 7000. [Val Acc 71%, Loss 0.594271]
# Iter 7500. [Val Acc 71%, Loss 0.592437]
# Iter 8000. [Val Acc 71%, Loss 0.590749]
# Iter 8500. [Val Acc 72%, Loss 0.589199]
# Iter 9000. [Val Acc 72%, Loss 0.587757]
# Iter 9500. [Val Acc 72%, Loss 0.586420]
# Iter 10000. [Val Acc 72%, Loss 0.585172]
# Iter 500. [Val Acc 67%, Loss 0.666318]
# Iter 1000. [Val Acc 68%, Loss 0.650524]
# Iter 1500. [Val Acc 69%, Loss 0.639469]
# Iter 2000. [Val Acc 69%, Loss 0.631049]
# Iter 2500. [Val Acc 69%, Loss 0.624318]
# Iter 3000. [Val Acc 70%, Loss 0.618784]
# Iter 3500. [Val Acc 70%, Loss 0.614128]
# Iter 4000. [Val Acc 70%, Loss 0.610151]
# Iter 4500. [Val Acc 71%, Loss 0.606687]
# Iter 5000. [Val Acc 71%, Loss 0.603627]
# Iter 5500. [Val Acc 71%, Loss 0.600912]
# Iter 6000. [Val Acc 71%, Loss 0.598474]
# Iter 6500. [Val Acc 71%, Loss 0.596271]
# Iter 7000. [Val Acc 71%, Loss 0.594264]
# Iter 7500. [Val Acc 71%, Loss 0.592436]
# Iter 8000. [Val Acc 71%, Loss 0.590749]
# Iter 8500. [Val Acc 72%, Loss 0.589197]
# Iter 9000. [Val Acc 72%, Loss 0.587756]
# Iter 9500. [Val Acc 72%, Loss 0.586419]
# Iter 10000. [Val Acc 72%, Loss 0.585172]
# Iter 500. [Val Acc 67%, Loss 0.666317]
# Iter 1000. [Val Acc 68%, Loss 0.650540]
# Iter 1500. [Val Acc 69%, Loss 0.639474]
# Iter 2000. [Val Acc 69%, Loss 0.631040]
# Iter 2500. [Val Acc 69%, Loss 0.624317]
# Iter 3000. [Val Acc 70%, Loss 0.618787]
# Iter 3500. [Val Acc 70%, Loss 0.614131]
# Iter 4000. [Val Acc 70%, Loss 0.610147]
# Iter 4500. [Val Acc 71%, Loss 0.606677]
# Iter 5000. [Val Acc 71%, Loss 0.603630]
# Iter 5500. [Val Acc 71%, Loss 0.600906]
# Iter 6000. [Val Acc 71%, Loss 0.598474]
# Iter 6500. [Val Acc 71%, Loss 0.596272]
# Iter 7000. [Val Acc 71%, Loss 0.594269]
# Iter 7500. [Val Acc 71%, Loss 0.592431]
# Iter 8000. [Val Acc 71%, Loss 0.590751]
# Iter 8500. [Val Acc 72%, Loss 0.589197]
# Iter 9000. [Val Acc 72%, Loss 0.587758]
# Iter 9500. [Val Acc 72%, Loss 0.586419]
# Iter 10000. [Val Acc 72%, Loss 0.585172]
# Iter 500. [Val Acc 67%, Loss 0.666316]
# Iter 1000. [Val Acc 68%, Loss 0.650547]
# Iter 1500. [Val Acc 69%, Loss 0.639467]
# Iter 2000. [Val Acc 69%, Loss 0.631038]
# Iter 2500. [Val Acc 69%, Loss 0.624317]
# Iter 3000. [Val Acc 70%, Loss 0.618790]
# Iter 3500. [Val Acc 70%, Loss 0.614134]
# Iter 4000. [Val Acc 70%, Loss 0.610149]
# Iter 4500. [Val Acc 71%, Loss 0.606679]
# Iter 5000. [Val Acc 71%, Loss 0.603625]
# Iter 5500. [Val Acc 71%, Loss 0.600914]
# Iter 6000. [Val Acc 71%, Loss 0.598474]
# Iter 6500. [Val Acc 71%, Loss 0.596271]
# Iter 7000. [Val Acc 71%, Loss 0.594272]
# Iter 7500. [Val Acc 71%, Loss 0.592438]
# Iter 8000. [Val Acc 71%, Loss 0.590752]
# Iter 8500. [Val Acc 72%, Loss 0.589197]
# Iter 9000. [Val Acc 72%, Loss 0.587760]
# Iter 9500. [Val Acc 72%, Loss 0.586422]
# Iter 10000. [Val Acc 72%, Loss 0.585175]
# Iter 500. [Val Acc 67%, Loss 0.666309]
# Iter 1000. [Val Acc 68%, Loss 0.650533]
# Iter 1500. [Val Acc 69%, Loss 0.639474]
# Iter 2000. [Val Acc 69%, Loss 0.631041]
# Iter 2500. [Val Acc 70%, Loss 0.624320]
# Iter 3000. [Val Acc 70%, Loss 0.618788]
# Iter 3500. [Val Acc 70%, Loss 0.614138]
# Iter 4000. [Val Acc 70%, Loss 0.610150]
# Iter 4500. [Val Acc 71%, Loss 0.606678]
# Iter 5000. [Val Acc 71%, Loss 0.603626]
# Iter 5500. [Val Acc 71%, Loss 0.600913]
# Iter 6000. [Val Acc 71%, Loss 0.598477]
# Iter 6500. [Val Acc 71%, Loss 0.596271]
# Iter 7000. [Val Acc 71%, Loss 0.594269]
# Iter 7500. [Val Acc 71%, Loss 0.592438]
# Iter 8000. [Val Acc 71%, Loss 0.590753]
# Iter 8500. [Val Acc 72%, Loss 0.589198]
# Iter 9000. [Val Acc 72%, Loss 0.587757]
# Iter 9500. [Val Acc 72%, Loss 0.586421]
# Iter 10000. [Val Acc 72%, Loss 0.585173]
# Iter 500. [Val Acc 67%, Loss 0.666326]
# Iter 1000. [Val Acc 68%, Loss 0.650535]
# Iter 1500. [Val Acc 68%, Loss 0.639470]
# Iter 2000. [Val Acc 69%, Loss 0.631036]
# Iter 2500. [Val Acc 69%, Loss 0.624311]
# Iter 3000. [Val Acc 70%, Loss 0.618783]
# Iter 3500. [Val Acc 70%, Loss 0.614129]
# Iter 4000. [Val Acc 70%, Loss 0.610143]
# Iter 4500. [Val Acc 71%, Loss 0.606678]
# Iter 5000. [Val Acc 71%, Loss 0.603625]
# Iter 5500. [Val Acc 71%, Loss 0.600910]
# Iter 6000. [Val Acc 71%, Loss 0.598474]
# Iter 6500. [Val Acc 71%, Loss 0.596271]
# Iter 7000. [Val Acc 71%, Loss 0.594268]
# Iter 7500. [Val Acc 71%, Loss 0.592436]
# Iter 8000. [Val Acc 71%, Loss 0.590753]
# Iter 8500. [Val Acc 72%, Loss 0.589198]
# Iter 9000. [Val Acc 72%, Loss 0.587758]
# Iter 9500. [Val Acc 72%, Loss 0.586419]
# Iter 10000. [Val Acc 72%, Loss 0.585173]
# Iter 500. [Val Acc 67%, Loss 0.666308]
# Iter 1000. [Val Acc 68%, Loss 0.650544]
# Iter 1500. [Val Acc 69%, Loss 0.639469]
# Iter 2000. [Val Acc 69%, Loss 0.631042]
# Iter 2500. [Val Acc 69%, Loss 0.624316]
# Iter 3000. [Val Acc 70%, Loss 0.618789]
# Iter 3500. [Val Acc 70%, Loss 0.614131]
# Iter 4000. [Val Acc 70%, Loss 0.610148]
# Iter 4500. [Val Acc 71%, Loss 0.606680]
# Iter 5000. [Val Acc 71%, Loss 0.603628]
# Iter 5500. [Val Acc 71%, Loss 0.600912]
# Iter 6000. [Val Acc 71%, Loss 0.598475]
# Iter 6500. [Val Acc 71%, Loss 0.596272]
# Iter 7000. [Val Acc 71%, Loss 0.594268]
# Iter 7500. [Val Acc 71%, Loss 0.592435]
# Iter 8000. [Val Acc 71%, Loss 0.590751]
# Iter 8500. [Val Acc 72%, Loss 0.589200]
# Iter 9000. [Val Acc 72%, Loss 0.587758]
# Iter 9500. [Val Acc 72%, Loss 0.586420]
# Iter 10000. [Val Acc 72%, Loss 0.585174]
# Iter 500. [Val Acc 67%, Loss 0.666322]
# Iter 1000. [Val Acc 68%, Loss 0.650536]
# Iter 1500. [Val Acc 69%, Loss 0.639469]
# Iter 2000. [Val Acc 69%, Loss 0.631039]
# Iter 2500. [Val Acc 70%, Loss 0.624316]
# Iter 3000. [Val Acc 70%, Loss 0.618787]
# Iter 3500. [Val Acc 70%, Loss 0.614132]
# Iter 4000. [Val Acc 70%, Loss 0.610144]
# Iter 4500. [Val Acc 71%, Loss 0.606678]
# Iter 5000. [Val Acc 71%, Loss 0.603625]
# Iter 5500. [Val Acc 71%, Loss 0.600909]
# Iter 6000. [Val Acc 71%, Loss 0.598474]
# Iter 6500. [Val Acc 71%, Loss 0.596271]
# Iter 7000. [Val Acc 71%, Loss 0.594267]
# Iter 7500. [Val Acc 71%, Loss 0.592435]
# Iter 8000. [Val Acc 71%, Loss 0.590751]
# Iter 8500. [Val Acc 72%, Loss 0.589195]
# Iter 9000. [Val Acc 72%, Loss 0.587756]
# Iter 9500. [Val Acc 72%, Loss 0.586418]
# Iter 10000. [Val Acc 72%, Loss 0.585170]
# ...
# Iter 2000. [Val Acc 72%, Loss 0.585166]
# Iter 2500. [Val Acc 72%, Loss 0.580043]
# Iter 3000. [Val Acc 72%, Loss 0.576206]
# Iter 3500. [Val Acc 72%, Loss 0.573267]
# Iter 4000. [Val Acc 72%, Loss 0.570966]
# Iter 4500. [Val Acc 72%, Loss 0.569160]
# Iter 5000. [Val Acc 73%, Loss 0.567688]
# Iter 5500. [Val Acc 73%, Loss 0.566498]
# Iter 6000. [Val Acc 73%, Loss 0.565508]
# Iter 6500. [Val Acc 73%, Loss 0.564704]
# Iter 7000. [Val Acc 73%, Loss 0.564050]
# Iter 7500. [Val Acc 73%, Loss 0.563475]
# Iter 8000. [Val Acc 73%, Loss 0.563004]
# Iter 8500. [Val Acc 73%, Loss 0.562594]
# Iter 9000. [Val Acc 73%, Loss 0.562251]
# Iter 9500. [Val Acc 73%, Loss 0.561968]
# Iter 10000. [Val Acc 73%, Loss 0.561717]
# Iter 500. [Val Acc 70%, Loss 0.624313]
# Iter 1000. [Val Acc 71%, Loss 0.603602]
# Iter 1500. [Val Acc 71%, Loss 0.592435]
# Iter 2000. [Val Acc 72%, Loss 0.585176]
# Iter 2500. [Val Acc 72%, Loss 0.580034]
# Iter 3000. [Val Acc 72%, Loss 0.576198]
# Iter 3500. [Val Acc 72%, Loss 0.573271]
# Iter 4000. [Val Acc 72%, Loss 0.570983]
# Iter 4500. [Val Acc 72%, Loss 0.569162]
# Iter 5000. [Val Acc 73%, Loss 0.567698]
# Iter 5500. [Val Acc 73%, Loss 0.566499]
# Iter 6000. [Val Acc 73%, Loss 0.565521]
# Iter 6500. [Val Acc 73%, Loss 0.564703]
# Iter 7000. [Val Acc 73%, Loss 0.564036]
# Iter 7500. [Val Acc 73%, Loss 0.563479]
# Iter 8000. [Val Acc 73%, Loss 0.563004]
# Iter 8500. [Val Acc 73%, Loss 0.562597]
# Iter 9000. [Val Acc 73%, Loss 0.562251]
# Iter 9500. [Val Acc 73%, Loss 0.561956]
# Iter 10000. [Val Acc 73%, Loss 0.561715]
# Iter 500. [Val Acc 69%, Loss 0.624314]
# Iter 1000. [Val Acc 71%, Loss 0.603612]
# Iter 1500. [Val Acc 71%, Loss 0.592437]
# Iter 2000. [Val Acc 72%, Loss 0.585171]
# Iter 2500. [Val Acc 72%, Loss 0.580025]
# Iter 3000. [Val Acc 72%, Loss 0.576212]
# Iter 3500. [Val Acc 72%, Loss 0.573279]
# Iter 4000. [Val Acc 72%, Loss 0.570975]
# Iter 4500. [Val Acc 72%, Loss 0.569167]
# Iter 5000. [Val Acc 73%, Loss 0.567688]
# Iter 5500. [Val Acc 73%, Loss 0.566499]
# Iter 6000. [Val Acc 73%, Loss 0.565520]
# Iter 6500. [Val Acc 73%, Loss 0.564719]
# Iter 7000. [Val Acc 73%, Loss 0.564035]
# Iter 7500. [Val Acc 73%, Loss 0.563464]
# Iter 8000. [Val Acc 73%, Loss 0.563002]
# Iter 8500. [Val Acc 73%, Loss 0.562599]
# Iter 9000. [Val Acc 73%, Loss 0.562249]
# Iter 9500. [Val Acc 73%, Loss 0.561964]
# Iter 10000. [Val Acc 73%, Loss 0.561707]
# Iter 500. [Val Acc 70%, Loss 0.624284]
# Iter 1000. [Val Acc 71%, Loss 0.603618]
# Iter 1500. [Val Acc 71%, Loss 0.592426]
# Iter 2000. [Val Acc 72%, Loss 0.585162]
# Iter 2500. [Val Acc 72%, Loss 0.580026]
# Iter 3000. [Val Acc 72%, Loss 0.576201]
# Iter 3500. [Val Acc 72%, Loss 0.573271]
# Iter 4000. [Val Acc 72%, Loss 0.570980]
# Iter 4500. [Val Acc 72%, Loss 0.569155]
# Iter 5000. [Val Acc 73%, Loss 0.567688]
# Iter 5500. [Val Acc 73%, Loss 0.566490]
# Iter 6000. [Val Acc 73%, Loss 0.565515]
# Iter 6500. [Val Acc 73%, Loss 0.564716]
# Iter 7000. [Val Acc 73%, Loss 0.564039]
# Iter 7500. [Val Acc 73%, Loss 0.563475]
# Iter 8000. [Val Acc 73%, Loss 0.563004]
# Iter 8500. [Val Acc 73%, Loss 0.562594]
# Iter 9000. [Val Acc 73%, Loss 0.562246]
# Iter 9500. [Val Acc 73%, Loss 0.561966]
# Iter 10000. [Val Acc 73%, Loss 0.561714]
# Iter 500. [Val Acc 70%, Loss 0.624291]
# Iter 1000. [Val Acc 71%, Loss 0.603623]
# Iter 1500. [Val Acc 71%, Loss 0.592427]
# Iter 2000. [Val Acc 72%, Loss 0.585172]
# Iter 2500. [Val Acc 72%, Loss 0.580026]
# Iter 3000. [Val Acc 72%, Loss 0.576204]
# Iter 3500. [Val Acc 72%, Loss 0.573274]
# Iter 4000. [Val Acc 72%, Loss 0.570982]
# Iter 4500. [Val Acc 72%, Loss 0.569155]
# Iter 5000. [Val Acc 73%, Loss 0.567693]
# Iter 5500. [Val Acc 73%, Loss 0.566505]
# Iter 6000. [Val Acc 73%, Loss 0.565523]
# Iter 6500. [Val Acc 73%, Loss 0.564719]
# Iter 7000. [Val Acc 73%, Loss 0.564040]
# Iter 7500. [Val Acc 73%, Loss 0.563483]
# Iter 8000. [Val Acc 73%, Loss 0.563006]
# Iter 8500. [Val Acc 73%, Loss 0.562606]
# Iter 9000. [Val Acc 73%, Loss 0.562259]
# Iter 9500. [Val Acc 73%, Loss 0.561960]
# Iter 10000. [Val Acc 73%, Loss 0.561716]
# Iter 500. [Val Acc 69%, Loss 0.624293]
# Iter 1000. [Val Acc 71%, Loss 0.603629]
# Iter 1500. [Val Acc 71%, Loss 0.592438]
# Iter 2000. [Val Acc 72%, Loss 0.585166]
# Iter 2500. [Val Acc 72%, Loss 0.580027]
# Iter 3000. [Val Acc 72%, Loss 0.576211]
# Iter 3500. [Val Acc 72%, Loss 0.573277]
# Iter 4000. [Val Acc 72%, Loss 0.570977]
# Iter 4500. [Val Acc 73%, Loss 0.569156]
# Iter 5000. [Val Acc 73%, Loss 0.567692]
# Iter 5500. [Val Acc 73%, Loss 0.566505]
# Iter 6000. [Val Acc 73%, Loss 0.565526]
# Iter 6500. [Val Acc 73%, Loss 0.564711]
# Iter 7000. [Val Acc 73%, Loss 0.564040]
# Iter 7500. [Val Acc 73%, Loss 0.563472]
# Iter 8000. [Val Acc 73%, Loss 0.563002]
# Iter 8500. [Val Acc 73%, Loss 0.562599]
# Iter 9000. [Val Acc 73%, Loss 0.562257]
# Iter 9500. [Val Acc 73%, Loss 0.561961]
# Iter 10000. [Val Acc 73%, Loss 0.561710]
# Iter 500. [Val Acc 69%, Loss 0.624291]
# Iter 1000. [Val Acc 71%, Loss 0.603625]
# Iter 1500. [Val Acc 71%, Loss 0.592430]
# Iter 2000. [Val Acc 72%, Loss 0.585168]
# Iter 2500. [Val Acc 72%, Loss 0.580030]
# Iter 3000. [Val Acc 72%, Loss 0.576202]
# Iter 3500. [Val Acc 72%, Loss 0.573277]
# Iter 4000. [Val Acc 72%, Loss 0.570981]
# Iter 4500. [Val Acc 72%, Loss 0.569158]
# Iter 5000. [Val Acc 73%, Loss 0.567692]
# Iter 5500. [Val Acc 73%, Loss 0.566499]
# Iter 6000. [Val Acc 73%, Loss 0.565521]
# Iter 6500. [Val Acc 73%, Loss 0.564714]
# Iter 7000. [Val Acc 73%, Loss 0.564044]
# Iter 7500. [Val Acc 73%, Loss 0.563479]
# Iter 8000. [Val Acc 73%, Loss 0.563002]
# Iter 8500. [Val Acc 73%, Loss 0.562600]
# Iter 9000. [Val Acc 73%, Loss 0.562253]
# Iter 9500. [Val Acc 73%, Loss 0.561957]
# Iter 10000. [Val Acc 73%, Loss 0.561708]
# Iter 500. [Val Acc 69%, Loss 0.624330]
# Iter 1000. [Val Acc 71%, Loss 0.603607]
# Iter 1500. [Val Acc 71%, Loss 0.592429]
# Iter 2000. [Val Acc 72%, Loss 0.585175]
# Iter 2500. [Val Acc 72%, Loss 0.580027]
# Iter 3000. [Val Acc 72%, Loss 0.576203]
# Iter 3500. [Val Acc 72%, Loss 0.573277]
# Iter 4000. [Val Acc 72%, Loss 0.570979]
# Iter 4500. [Val Acc 72%, Loss 0.569157]
# Iter 5000. [Val Acc 73%, Loss 0.567689]
# Iter 5500. [Val Acc 73%, Loss 0.566498]
# Iter 6000. [Val Acc 73%, Loss 0.565520]
# Iter 6500. [Val Acc 73%, Loss 0.564715]
# Iter 7000. [Val Acc 73%, Loss 0.564040]
# Iter 7500. [Val Acc 73%, Loss 0.563480]
# Iter 8000. [Val Acc 73%, Loss 0.563003]
# Iter 8500. [Val Acc 73%, Loss 0.562595]
# Iter 9000. [Val Acc 73%, Loss 0.562255]
# Iter 9500. [Val Acc 73%, Loss 0.561965]
# Iter 10000. [Val Acc 73%, Loss 0.561708]
# Iter 500. [Val Acc 71%, Loss 0.603565]
# Iter 1000. [Val Acc 72%, Loss 0.585286]
# Iter 1500. [Val Acc 72%, Loss 0.576285]
# Iter 2000. [Val Acc 72%, Loss 0.571066]
# Iter 2500. [Val Acc 73%, Loss 0.567693]
# Iter 3000. [Val Acc 73%, Loss 0.565543]
# Iter 3500. [Val Acc 73%, Loss 0.564020]
# Iter 4000. [Val Acc 73%, Loss 0.563022]
# Iter 4500. [Val Acc 73%, Loss 0.562330]
# Iter 5000. [Val Acc 73%, Loss 0.561768]
# Iter 5500. [Val Acc 73%, Loss 0.561308]
# Iter 6000. [Val Acc 73%, Loss 0.561039]
# Iter 6500. [Val Acc 73%, Loss 0.560816]
# Iter 7000. [Val Acc 73%, Loss 0.560611]
# Iter 7500. [Val Acc 73%, Loss 0.560454]
# Iter 8000. [Val Acc 73%, Loss 0.560333]
# Iter 8500. [Val Acc 73%, Loss 0.560329]
# Iter 9000. [Val Acc 73%, Loss 0.560164]
# Iter 9500. [Val Acc 73%, Loss 0.560094]
# Iter 10000. [Val Acc 73%, Loss 0.560081]
# Iter 500. [Val Acc 71%, Loss 0.603545]
# Iter 1000. [Val Acc 72%, Loss 0.585117]
# Iter 1500. [Val Acc 72%, Loss 0.576230]
# Iter 2000. [Val Acc 72%, Loss 0.570973]
# Iter 2500. [Val Acc 73%, Loss 0.567739]
# Iter 3000. [Val Acc 73%, Loss 0.565546]
# Iter 3500. [Val Acc 73%, Loss 0.564059]
# Iter 4000. [Val Acc 73%, Loss 0.562982]
# Iter 4500. [Val Acc 73%, Loss 0.562230]
# Iter 5000. [Val Acc 73%, Loss 0.561710]
# Iter 5500. [Val Acc 73%, Loss 0.561315]
# Iter 6000. [Val Acc 73%, Loss 0.561034]
# Iter 6500. [Val Acc 73%, Loss 0.560745]
# Iter 7000. [Val Acc 73%, Loss 0.560626]
# Iter 7500. [Val Acc 73%, Loss 0.560412]
# Iter 8000. [Val Acc 73%, Loss 0.560320]
# Iter 8500. [Val Acc 73%, Loss 0.560203]
# Iter 9000. [Val Acc 73%, Loss 0.560132]
# Iter 9500. [Val Acc 73%, Loss 0.560067]
# Iter 10000. [Val Acc 73%, Loss 0.560037]
# Iter 500. [Val Acc 71%, Loss 0.603616]
# Iter 1000. [Val Acc 72%, Loss 0.585162]
# Iter 1500. [Val Acc 72%, Loss 0.576194]
# Iter 2000. [Val Acc 72%, Loss 0.570995]
# Iter 2500. [Val Acc 73%, Loss 0.567679]
# Iter 3000. [Val Acc 73%, Loss 0.565532]
# Iter 3500. [Val Acc 73%, Loss 0.564070]
# Iter 4000. [Val Acc 73%, Loss 0.563000]
# Iter 4500. [Val Acc 73%, Loss 0.562264]
# Iter 5000. [Val Acc 73%, Loss 0.561695]
# Iter 5500. [Val Acc 73%, Loss 0.561306]
# Iter 6000. [Val Acc 73%, Loss 0.560989]
# Iter 6500. [Val Acc 73%, Loss 0.560792]
# Iter 7000. [Val Acc 73%, Loss 0.560576]
# Iter 7500. [Val Acc 73%, Loss 0.560445]
# Iter 8000. [Val Acc 73%, Loss 0.560324]
# Iter 8500. [Val Acc 73%, Loss 0.560236]
# Iter 9000. [Val Acc 73%, Loss 0.560151]
# Iter 9500. [Val Acc 73%, Loss 0.560073]
# Iter 10000. [Val Acc 73%, Loss 0.560056]
# Iter 500. [Val Acc 71%, Loss 0.603643]
# Iter 1000. [Val Acc 72%, Loss 0.585141]
# Iter 1500. [Val Acc 72%, Loss 0.576266]
# Iter 2000. [Val Acc 72%, Loss 0.570979]
# Iter 2500. [Val Acc 73%, Loss 0.567704]
# Iter 3000. [Val Acc 73%, Loss 0.565516]
# Iter 3500. [Val Acc 73%, Loss 0.564042]
# Iter 4000. [Val Acc 73%, Loss 0.563007]
# Iter 4500. [Val Acc 73%, Loss 0.562248]
# Iter 5000. [Val Acc 73%, Loss 0.561706]
# Iter 5500. [Val Acc 73%, Loss 0.561286]
# Iter 6000. [Val Acc 73%, Loss 0.560988]
# Iter 6500. [Val Acc 73%, Loss 0.560779]
# Iter 7000. [Val Acc 73%, Loss 0.560581]
# Iter 7500. [Val Acc 73%, Loss 0.560424]
# Iter 8000. [Val Acc 73%, Loss 0.560304]
# Iter 8500. [Val Acc 73%, Loss 0.560239]
# Iter 9000. [Val Acc 73%, Loss 0.560146]
# Iter 9500. [Val Acc 73%, Loss 0.560083]
# Iter 10000. [Val Acc 73%, Loss 0.560036]
# Iter 500. [Val Acc 71%, Loss 0.603628]
# Iter 1000. [Val Acc 72%, Loss 0.585150]
# Iter 1500. [Val Acc 72%, Loss 0.576209]
# Iter 2000. [Val Acc 72%, Loss 0.570996]
# Iter 2500. [Val Acc 73%, Loss 0.567675]
# Iter 3000. [Val Acc 73%, Loss 0.565522]
# Iter 3500. [Val Acc 73%, Loss 0.564035]
# Iter 4000. [Val Acc 73%, Loss 0.562994]
# Iter 4500. [Val Acc 73%, Loss 0.562279]
# Iter 5000. [Val Acc 73%, Loss 0.561705]
# Iter 5500. [Val Acc 73%, Loss 0.561318]
# Iter 6000. [Val Acc 73%, Loss 0.560989]
# Iter 6500. [Val Acc 73%, Loss 0.560753]
# Iter 7000. [Val Acc 73%, Loss 0.560593]
# Iter 7500. [Val Acc 73%, Loss 0.560412]
# Iter 8000. [Val Acc 73%, Loss 0.560313]
# Iter 8500. [Val Acc 73%, Loss 0.560217]
# Iter 9000. [Val Acc 73%, Loss 0.560156]
# Iter 9500. [Val Acc 73%, Loss 0.560091]
# Iter 10000. [Val Acc 73%, Loss 0.560015]
# Iter 500. [Val Acc 71%, Loss 0.603617]
# Iter 1000. [Val Acc 72%, Loss 0.585193]
# Iter 1500. [Val Acc 72%, Loss 0.576204]
# Iter 2000. [Val Acc 72%, Loss 0.570999]
# Iter 2500. [Val Acc 73%, Loss 0.567688]
# Iter 3000. [Val Acc 73%, Loss 0.565527]
# Iter 3500. [Val Acc 73%, Loss 0.564051]
# Iter 4000. [Val Acc 73%, Loss 0.563011]
# Iter 4500. [Val Acc 73%, Loss 0.562255]
# Iter 5000. [Val Acc 73%, Loss 0.561719]
# Iter 5500. [Val Acc 73%, Loss 0.561307]
# Iter 6000. [Val Acc 73%, Loss 0.561004]
# Iter 6500. [Val Acc 73%, Loss 0.560735]
# Iter 7000. [Val Acc 73%, Loss 0.560570]
# Iter 7500. [Val Acc 73%, Loss 0.560427]
# Iter 8000. [Val Acc 73%, Loss 0.560314]
# Iter 8500. [Val Acc 73%, Loss 0.560220]
# Iter 9000. [Val Acc 73%, Loss 0.560155]
# Iter 9500. [Val Acc 73%, Loss 0.560085]
# Iter 10000. [Val Acc 73%, Loss 0.560020]
# Iter 500. [Val Acc 71%, Loss 0.603602]
# Iter 1000. [Val Acc 72%, Loss 0.585151]
# Iter 1500. [Val Acc 72%, Loss 0.576196]
# Iter 2000. [Val Acc 72%, Loss 0.570982]
# Iter 2500. [Val Acc 73%, Loss 0.567685]
# Iter 3000. [Val Acc 73%, Loss 0.565510]
# Iter 3500. [Val Acc 73%, Loss 0.564044]
# Iter 4000. [Val Acc 73%, Loss 0.563009]
# Iter 4500. [Val Acc 73%, Loss 0.562254]
# Iter 5000. [Val Acc 73%, Loss 0.561711]
# Iter 5500. [Val Acc 73%, Loss 0.561315]
# Iter 6000. [Val Acc 73%, Loss 0.560985]
# Iter 6500. [Val Acc 73%, Loss 0.560750]
# Iter 7000. [Val Acc 73%, Loss 0.560569]
# Iter 7500. [Val Acc 73%, Loss 0.560428]
# Iter 8000. [Val Acc 73%, Loss 0.560317]
# Iter 8500. [Val Acc 73%, Loss 0.560218]
# Iter 9000. [Val Acc 73%, Loss 0.560142]
# Iter 9500. [Val Acc 73%, Loss 0.560093]
# Iter 10000. [Val Acc 73%, Loss 0.560024]
# Iter 500. [Val Acc 71%, Loss 0.603607]
# Iter 1000. [Val Acc 72%, Loss 0.585167]
# Iter 1500. [Val Acc 72%, Loss 0.576186]
# Iter 2000. [Val Acc 72%, Loss 0.570986]
# Iter 2500. [Val Acc 73%, Loss 0.567694]
# Iter 3000. [Val Acc 73%, Loss 0.565511]
# Iter 3500. [Val Acc 73%, Loss 0.564042]
# Iter 4000. [Val Acc 73%, Loss 0.563001]
# Iter 4500. [Val Acc 73%, Loss 0.562256]
# Iter 5000. [Val Acc 73%, Loss 0.561701]
# Iter 5500. [Val Acc 73%, Loss 0.561306]
# Iter 6000. [Val Acc 73%, Loss 0.560988]
# Iter 6500. [Val Acc 73%, Loss 0.560755]
# Iter 7000. [Val Acc 73%, Loss 0.560570]
# Iter 7500. [Val Acc 73%, Loss 0.560422]
# Iter 8000. [Val Acc 73%, Loss 0.560311]
# Iter 8500. [Val Acc 73%, Loss 0.560218]
# Iter 9000. [Val Acc 73%, Loss 0.560146]
# Iter 9500. [Val Acc 73%, Loss 0.560074]
# Iter 10000. [Val Acc 73%, Loss 0.560023]
# Iter 500. [Val Acc 71%, Loss 0.603607]
# Iter 1000. [Val Acc 72%, Loss 0.585171]
# Iter 1500. [Val Acc 72%, Loss 0.576190]
# Iter 2000. [Val Acc 72%, Loss 0.570980]
# Iter 2500. [Val Acc 73%, Loss 0.567694]
# Iter 3000. [Val Acc 73%, Loss 0.565523]
# Iter 3500. [Val Acc 73%, Loss 0.564036]
# Iter 4000. [Val Acc 73%, Loss 0.563003]
# Iter 4500. [Val Acc 73%, Loss 0.562257]
# Iter 5000. [Val Acc 73%, Loss 0.561706]
# Iter 5500. [Val Acc 73%, Loss 0.561308]
# Iter 6000. [Val Acc 73%, Loss 0.560997]
# Iter 6500. [Val Acc 73%, Loss 0.560753]
# Iter 7000. [Val Acc 73%, Loss 0.560573]
# Iter 7500. [Val Acc 73%, Loss 0.560437]
# Iter 8000. [Val Acc 73%, Loss 0.560312]
# Iter 8500. [Val Acc 73%, Loss 0.560221]
# Iter 9000. [Val Acc 73%, Loss 0.560153]
# Iter 9500. [Val Acc 73%, Loss 0.560074]
# Iter 10000. [Val Acc 73%, Loss 0.560018]
# Iter 500. [Val Acc 71%, Loss 0.603633]
# Iter 1000. [Val Acc 72%, Loss 0.585161]
# Iter 1500. [Val Acc 72%, Loss 0.576205]
# Iter 2000. [Val Acc 72%, Loss 0.570980]
# Iter 2500. [Val Acc 73%, Loss 0.567679]
# Iter 3000. [Val Acc 73%, Loss 0.565516]
# Iter 3500. [Val Acc 73%, Loss 0.564034]
# Iter 4000. [Val Acc 73%, Loss 0.563002]
# Iter 4500. [Val Acc 73%, Loss 0.562245]
# Iter 5000. [Val Acc 73%, Loss 0.561706]
# Iter 5500. [Val Acc 73%, Loss 0.561302]
# Iter 6000. [Val Acc 73%, Loss 0.560990]
# Iter 6500. [Val Acc 73%, Loss 0.560762]
# Iter 7000. [Val Acc 73%, Loss 0.560572]
# Iter 7500. [Val Acc 73%, Loss 0.560432]
# Iter 8000. [Val Acc 73%, Loss 0.560302]
# Iter 8500. [Val Acc 73%, Loss 0.560210]
# Iter 9000. [Val Acc 73%, Loss 0.560138]
# Iter 9500. [Val Acc 73%, Loss 0.560081]
# Iter 10000. [Val Acc 73%, Loss 0.560022]
# Iter 500. [Val Acc 71%, Loss 0.603589]
# Iter 1000. [Val Acc 72%, Loss 0.585159]
# Iter 1500. [Val Acc 72%, Loss 0.576196]
# Iter 2000. [Val Acc 72%, Loss 0.570984]
# Iter 2500. [Val Acc 73%, Loss 0.567691]
# Iter 3000. [Val Acc 73%, Loss 0.565517]
# Iter 3500. [Val Acc 73%, Loss 0.564046]
# Iter 4000. [Val Acc 73%, Loss 0.563005]
# Iter 4500. [Val Acc 73%, Loss 0.562252]
# Iter 5000. [Val Acc 73%, Loss 0.561717]
# Iter 5500. [Val Acc 73%, Loss 0.561299]
# Iter 6000. [Val Acc 73%, Loss 0.560993]
# Iter 6500. [Val Acc 73%, Loss 0.560757]
# Iter 7000. [Val Acc 73%, Loss 0.560571]
# Iter 7500. [Val Acc 73%, Loss 0.560427]
# Iter 8000. [Val Acc 73%, Loss 0.560311]
# Iter 8500. [Val Acc 73%, Loss 0.560222]
# Iter 9000. [Val Acc 73%, Loss 0.560141]
# Iter 9500. [Val Acc 73%, Loss 0.560083]
# Iter 10000. [Val Acc 73%, Loss 0.560027]
# Iter 500. [Val Acc 71%, Loss 0.603629]
# Iter 1000. [Val Acc 72%, Loss 0.585163]
# Iter 1500. [Val Acc 72%, Loss 0.576201]
# Iter 2000. [Val Acc 72%, Loss 0.570967]
# Iter 2500. [Val Acc 73%, Loss 0.567692]
# Iter 3000. [Val Acc 73%, Loss 0.565521]
# Iter 3500. [Val Acc 73%, Loss 0.564034]
# Iter 4000. [Val Acc 73%, Loss 0.563008]
# Iter 4500. [Val Acc 73%, Loss 0.562257]
# Iter 5000. [Val Acc 73%, Loss 0.561721]
# Iter 5500. [Val Acc 73%, Loss 0.561302]
# Iter 6000. [Val Acc 73%, Loss 0.561001]
# Iter 6500. [Val Acc 73%, Loss 0.560760]
# Iter 7000. [Val Acc 73%, Loss 0.560573]
# Iter 7500. [Val Acc 73%, Loss 0.560424]
# Iter 8000. [Val Acc 73%, Loss 0.560317]
# Iter 8500. [Val Acc 73%, Loss 0.560222]
# Iter 9000. [Val Acc 73%, Loss 0.560145]
# Iter 9500. [Val Acc 73%, Loss 0.560087]
# Iter 10000. [Val Acc 73%, Loss 0.560026]
# Text(0.5, 1.0, 'Training accuracy (blue) and Validation accuracy (red) per iteration; $\\mu$=0.01 batch size=6000')

# %% [markdown]
# ### 2.7 Finding and saving optimal values
#
# Find the optimal value of ${\bf w}$ and $b$ in the means of accuracy using your code. Notice that the choice of $\mu$ and the batch size are important for this. Run the code below to save these parameters to a file in your google drive directory. submit to the moodle (alongside this file and the functions file) both the
# "assignment2_submission_optimal_weights.npy" file and "assignment2_submission_optimal_bias.npy" file.

# %%
#change these to the optimal weights and biases, leave the name the same
np.save(drive_path+"assignment2_submission_optimal_weights.npy",mem_opt_w)
np.save(drive_path+"assignment2_submission_optimal_bias.npy",mem_opt_b)

# %% [markdown]
# ### 2.8 Results
#
# Using the values of `w` and `b` from part 2.7, compute your training accuracy, validation accuracy,
# and test accuracy. Are there any differences between those three values? If so, why?

# %%
w = np.load(drive_path+"assignment2_submission_optimal_weights.npy")
b = np.load(drive_path+"assignment2_submission_optimal_bias.npy")

# Write your code here

train_acc = mem_trainingAcc[-1]
val_acc = mem_acc_list[-1]
test_acc = ML_DL_Functions2.get_accuracy(ML_DL_Functions2.pred(w,b,test_norm_xs), test_ts)

print('train_acc = ', train_acc, ' val_acc = ', val_acc, ' test_acc = ', test_acc)
# Out:
# train_acc =  0.7268333333333333  val_acc =  0.7298  test_acc =  0.7281555555555556

# %% [markdown]
# ### 2.9 Using Pytorch
# Writing a classifier like this is instructive, and helps you understand what happens when
# we train a model. However, in practice, we rarely write model building and training code
# from scratch. Instead, we typically use one of the well-tested libraries available in a package. The following example showes you how this task could have been achieved using the deep learning library, pytorch. The library greatly simplifies the steps needed to create a learning model. Though there is nothing you need to complete in this section we suggest you read this section thoroughly and make sure you understand all the code. In the next assignment you will need to build a deep learning model yourself.

# %% [markdown]
# The first step required to use the pytorch module is to create a class which will be our model. in this case we will use a linear layer with a costum size(in your assignment you used a 90,1 linear layer meaning an input size of 90 and an output size of 1). We also add a sigmoid function to restrict the values between 0 and 1.
#
# The forward function is called everytime you call the model by name. It is equivalent to the prediction function you wrote but it serves another purpose since it saves all the operations done to the tensor which can then be used to calculate the gradients.

# %%
import torch
class single_layer(torch.nn.Module):
  def __init__(self,input_size,output_size):
    super(single_layer,self).__init__()
    self.neuron = torch.nn.Linear(input_size,output_size)
    self.sigmoid = torch.nn.Sigmoid()

  def forward(self,X):
    out = self.neuron(X)
    out = self.sigmoid(out)
    return out

# %% [markdown]
# We can now create a new model.
#
# we don't have to write the binary cross entropy loss since it is already written for us(criterion).
#
# Also instead of writing the optimzation proccess which in our case was gradient descent(W[n+1] = w[n]-$\mu$dL/dW) we can use a pre built optimizer(SGD).

# %%
model = single_layer(90,1)
criterion = torch.nn.BCELoss()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.05)

# %% [markdown]
# There are a few pre-built training functions but usually the training function is written by hand. this function is similar to the one you wrote in this assignment only we now can use the pre-built tensor functions. Make sure you understood all the differences between the two:

# %%
import pdb
def train_model(model, criterion, optimizer, batch_size=100, max_iters=100):
  iter = 0
  cost_list = []
  acc_list  = []
  train_norm_xs_shuff = train_norm_xs
  train_ts_shuff = train_ts
  val_X_tensor = torch.tensor(val_norm_xs,dtype=torch.float32)
  while iter < max_iters:
    # shuffle the training set (there is code above for how to do this)
    reindex = np.random.permutation(len(train_norm_xs))
    train_norm_xs_shuff = train_norm_xs_shuff[reindex]
    train_ts_shuff = train_ts_shuff[reindex]

    for i in range(0, len(train_norm_xs), batch_size): # iterate over each minibatch
      # minibatch that we are working with:
      X = train_norm_xs_shuff[i:(i + batch_size)]
      t = train_ts_shuff[i:(i + batch_size), 0]

      # since len(train_norm_xs) does not divide batch_size evenly, we will skip over
      # the "last" minibatch
      if np.shape(X)[0] != batch_size:
        continue
      # change the numpy types into torches tensors
      X_tensor = torch.tensor(X,dtype=torch.float32)
      t_tensor = torch.tensor(t,dtype=torch.float32).unsqueeze(1) # the unsqueeze reshapes (N,) to (N,1)

      # a clean up step for PyTorch
      optimizer.zero_grad()
      # compute the prediction
      prediction = model(X_tensor)
      # compute the cost/loss
      loss = criterion(prediction,t_tensor)
      # calculate gradient(backpropegate)
      loss.backward()
      # update w and b(step)
      optimizer.step()
      # increment the iteration count
      iter += 1
      # compute and print the *validation* accuracy
      if (iter % 40 == 0):
        val_pred = model(val_X_tensor)
        val_acc = ML_DL_Functions2.get_accuracy(val_pred,val_ts)
        acc_list.append(val_acc)

        print("Iter %d. [Val Acc %.1f%%]" % (
                iter, val_acc * 100))

      if iter >= max_iters:
        break


  return acc_list

# %% [markdown]
# We can now run the training proccess. You should get pretty similar results to the ones from the model you wrote. Make sure that the results are in the same range and if not fix your model and try again.

# %%
reload_functions()
import ML_DL_Functions2
acc_list = train_model(model,criterion,optimizer,100,500)
# Out:
# Iter 40. [Val Acc 65.4%]
# Iter 80. [Val Acc 68.2%]
# Iter 120. [Val Acc 70.1%]
# Iter 160. [Val Acc 71.1%]
# Iter 200. [Val Acc 71.3%]
# Iter 240. [Val Acc 71.5%]
# Iter 280. [Val Acc 71.9%]
# Iter 320. [Val Acc 72.1%]
# Iter 360. [Val Acc 71.9%]
# Iter 400. [Val Acc 72.4%]
# Iter 440. [Val Acc 72.5%]
# Iter 480. [Val Acc 72.4%]

# %% [markdown]
# You can also try to change the model(add layers or change layers) change the optimizer or the hyperparameters and try to improve the validation accuracy. If you want a challenge you can try reach a validation accuracy of 75%
